# %%
import numpy as np
import pandas as pd
import ssl
import copy
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline
import re
import random
import pickle
from pprint import pprint

from imblearn.over_sampling import RandomOverSampler,SMOTE, ADASYN, SMOTENC, SVMSMOTE
from imblearn.pipeline import make_pipeline

from imblearn.under_sampling import RandomUnderSampler


from sklearn.metrics import hamming_loss, roc_auc_score
from sklearn.metrics import confusion_matrix 
from sklearn.model_selection import train_test_split 

from nltk.stem import PorterStemmer
from nltk.corpus import wordnet
from nltk.stem import WordNetLemmatizer
from nltk import pos_tag
from nltk.corpus import stopwords 
from nltk.tokenize import word_tokenize 
import wordcloud

from sklearn.pipeline import Pipeline
from sklearn.metrics import accuracy_score, recall_score, precision_score, f1_score, roc_curve
from sklearn.linear_model import LogisticRegression, SGDClassifier
from sklearn.feature_extraction.text import CountVectorizer
from sklearn.svm import LinearSVC, NuSVC
from sklearn.naive_bayes import MultinomialNB
from sklearn.feature_extraction.text import TfidfTransformer, TfidfVectorizer
from sklearn.multiclass import OneVsRestClassifier
from sklearn.preprocessing import MultiLabelBinarizer



import scikitplot as skplt
import matplotlib.pyplot as plt

from keras import optimizers
from keras.losses import binary_crossentropy
from keras.metrics import binary_accuracy
from keras.layers import Dense, Embedding, LSTM, SpatialDropout1D
from keras.models import Sequential
from keras.preprocessing.text import Tokenizer
from keras.preprocessing.sequence import pad_sequences
from keras.utils.np_utils import to_categorical
from keras.callbacks import EarlyStopping

from scipy.special import softmax

ssl._create_default_https_context = ssl._create_unverified_context

# %%
def clean_statement(statement):
#     x = re.sub('-', ' ', x)
    statement = re.sub('$', ' ', statement)
    statement = re.sub('[^A-Za-z]+', ' ', statement)
    statement = re.sub('[,|.|?|\n]|\t', '', statement)
    statement = re.sub('n\'t', ' ', statement)
    statement = re.sub('submission|submissions|Submission|submission|th ', '', statement)
    statement = re.sub('one|two|given|need', '', statement)
    
    return statement

# %%
def process_problem_statement(q_statement):
    
    q_statement = clean_statement(q_statement)
    
#     q_statement = re.sub('[^A-Za-z]+', ' ', q_statement)
    
    tokens = word_tokenize(q_statement)
    
    stoplist = set(stopwords.words('english'))
    
    word_list = [i for i in q_statement.lower().split() if i not in stoplist]
    
    ps = PorterStemmer()
    
#     word_list = [ps.stem(word) for word in word_list]
    
    q_statement = ' '.join(word_list)
    
#     print(q_statement)
    
    return q_statement

# %%
def process_problem_solution(solution):
    
#     solution = clean_statement(solution)
    
    tokens = word_tokenize(solution)
    
    stoplist = set(stopwords.words('english'))
    
    word_list = [i for i in solution.lower().split() if i not in stoplist]
    
#     ps = PorterStemmer()
    
#     word_list = [ps.stem(word) for word in word_list]
    
    solution = ' '.join(word_list)
    
#     print(q_statement)
    
    return solution

# %%
def process_tags(tags):
    
    tags = clean_statement(tags)
#     print(tags)
#     print(tag_col)
    tags = tags.strip()
    tags_present = list(re.split(' ',tags))
    
#     stoplist = set(stopwords.words('english'))
#     word_list = [i for i in solution.lower().split() if i not in stoplist]
    
#     tags_set = set(tags_present)
#     tags_diff = tags_set.difference(set(all_tags_list))
    
#     new_set = tags_set.difference(tags_diff)
#     print(new_set)
    return tags_present

# %%
def get_all_distinct_tags(tags_col):
    
    tags_list = []
    t_sets = set(tags_list)
    
    for row in tags_col:
#         for items in row:
#             print(items)
        t_sets = t_sets.union(set(row))
#         print(t_sets)
    tags_list = list(t_sets)
    
#     stoplist = set(stopwords.words('english'))
#     word_list = [i for i in tags_list if i not in stoplist]
    
    return tags_list

# %%
def process_problem_Languages(lang_col):
    
    lang_col = clean_statement(lang_col)
    
    return lang_col

# %%
global tags_list_codeforces , tags_list_codechef

tags_list_codeforces = ['dsu', 'trees', 'chinese remainder theorem', 'sortings', 'games', 'implementation', 'bitmasks',
              '*special', 'hashing', 'geometry', 'two pointers', 'combinatorics', 'flows', 'strings',
              'probabilities', 'data structures', 'ternary search', 'greedy', 'math', 'matrices',
              'divide and conquer', 'dfs and similar', 'constructive algorithms', 'brute force', 'dp',
              '2-sat', 'graph matchings', 'binary search', 'number theory', 'graphs', 'fft', 'shortest paths',
              'schedules', 'meet-in-the-middle', 'string suffix structures', 'expression parsing']


tags_list_codechef = ['tree', 'binarysearch', 'combinatorial', 'gcd', 'dijkstra','memoization','bipartite','fibonacci','sieve','map',
             'strings','suffix', 'geometry', 'knapsack', 'sorting', 'recursion', 'pointers', 'maxflow','binary', 'fenwick', 'game',
             'constructive','expo', 'graph', 'simulation', 'fft', 'algorithm', 'dfs', 'heap','bitmasking', 'hashing', 'basic', 
             'combinatorics', 'graphs', 'greedy', 'interactive', 'bfs', 'implementation', 'advanced', 'number', 'parsing', 'search',
             'prime', 'dynamic', 'deque', 'sets',  'disjoint','bitwise', 'digraph', 'theory', 'backtracking', 'probability','set', 
             'series', 'matrix', 'divide', 'kruskal','pattern', 'bruteforce','hard','trees','maths','enumeration','counting',
             'regex','tries', 'algebra', 'matching', 'multiset','euler', 'inversions', 'segment', 'permutation', 'stack', 
             'recurrence', 'dp', 'adhoc']

# %%
def validate_tags(Y):
    new_tags_list = []
    for tags in Y:
        i = 0
        while i<len(tags):
            if tags[i] not in tags_list_codechef:
                tags.remove(tags[i])
                continue
            i += 1
        new_tags_list.append(tags)
    return new_tags_list

# %%
def plot_class_distribution(Y,classes):
    
    count_list = [0]*Y.shape[1]
    
    for index in range(Y.shape[1]):
        
        count_list[index] = np.sum(Y[:,index])/Y.shape[0]
    
    plt.figure(figsize=(10, 15), dpi=100)
    
    plt.barh(classes,count_list, align='center', alpha=0.5)
#     plt.bar(np.arange(Y.shape[1]),count_list, align='center', alpha=0.5)
#     plt.plot(np.arange(Y.shape[1]),count_list)
    plt.show()

# %%
def reduce_sample_imbalance(X_train,Y_train):
    
    global X, Y, mlb, distinct_tags
    
    X_train = pd.DataFrame(X_train).values
    
    xtrain_col_index = X_train.shape[1]
    xtrain_row_index = X_train.shape[0]
    
    XY = np.column_stack((X_train,Y_train))
    
    labels = [0]*len(mlb.classes_)
    row_index_to_delete = []
    ratio = []
    
    for index in range(Y_train.shape[1]):
        ratio.append(np.sum(Y_train[:,index])/Y_train.shape[0])
        if np.sum(Y_train[:,index])/Y_train.shape[0] > 0.03:
            
            labels[index] = 1
            
    ratio.sort()

    count_deletions = [0]*len(labels)
    for index in range(len(labels)):
        if labels[index] == 1:

            count_deletions[index] = int(np.sum(Y_train[:,index]) * 0.97)    
    
    for index in range(Y_train.shape[0]):
        flag_to_delete = True
        
        for yindex in range(X_train.shape[1],XY.shape[1]):
            if Y_train[index][yindex-X_train.shape[1]] == 1:
                if labels[yindex-X_train.shape[1]] == 0 or count_deletions[yindex-X_train.shape[1]] <= 0:
                    flag_to_delete = False
                    break
        
        if flag_to_delete:
            row_index_to_delete.append(index)
            for i in range(len(count_deletions)):
                count_deletions[i] -= Y_train[index][i]
    
        if sum(count_deletions) <= 0:
            break;
            
    XY = np.delete(XY, row_index_to_delete,axis=0)
    
    ratio = []
    for index in range(X_train.shape[1],XY.shape[1]):
        ratio.append(np.sum(XY[:,index])/XY.shape[0])
    
    plot_class_distribution(XY[:,X_train.shape[1]:],mlb.classes_)
    
    
    data_to_repeat_index = [1]*XY.shape[0]
    labels = [0]*len(mlb.classes_)
    ratio = []
    for index in range(xtrain_col_index,XY.shape[1]):
        ratio.append(np.sum(XY[:,index])/XY.shape[0])
        if np.sum(XY[:,index])/XY.shape[0] < 0.02:
            labels[index-xtrain_col_index] = 1
    

    ratio.sort()
        
    for index in range(XY.shape[0]):
        for yindex in range(X_train.shape[1],XY.shape[1]):
            if XY[index][yindex] == 1 and labels[yindex-X_train.shape[1]] > 0:
                data_to_repeat_index[index] = 100
                labels[yindex-X_train.shape[1]] = -1
    
    XY = np.repeat(XY, repeats = data_to_repeat_index, axis=0)

    X_train = XY[:,0]
    Y_train = XY[:,1:]
            
    X_train = pd.Series(X_train)
    X_train = X_train.astype(str)
    Y_train = Y_train.astype('int') 
    return X_train,Y_train

# %%
def data_preprocessing():
    
    global X, Y, mlb, distinct_tags
    
    df = pd.read_csv("codechef_questions_v7.csv")
    print(df.shape)
    print(df.shape)
    print(df.columns)
    df = df.drop_duplicates()
    print(df.shape)
    
    
    X = copy.deepcopy(df["Solution"]+df["Difficultylevel"])
#     X = copy.deepcopy(df["Problem Statement"]+df["Difficultylevel"])
    Y = [process_tags(x) for x in df["tags"]]
    distinct_tags = get_all_distinct_tags(Y)
    
    
    mlb = MultiLabelBinarizer()
    Y = mlb.fit_transform(Y)
    
    plot_class_distribution(Y,mlb.classes_)

# %%
data_preprocessing()
# Out:
# (29320, 7)
# (29320, 7)
# Index(['Unnamed: 0', 'Unnamed: 0.1', 'Unnamed: 0.1.1.1', 'Difficultylevel',
#        'Problem Statement', 'Solution', 'tags'],
#       dtype='object')
# (29320, 7)

# %%
global X, Y, mlb, distinct_tags

X_train, X_validation, Y_train, Y_validation = train_test_split(X, Y, test_size = 0.2, random_state = 0)

plot_class_distribution(Y_train,mlb.classes_)
X_train,Y_train = reduce_sample_imbalance(X_train,Y_train)
plot_class_distribution(Y_train,mlb.classes_)
plot_class_distribution(Y_validation,mlb.classes_)


classifier = make_pipeline(
    CountVectorizer(ngram_range = (1,3),binary = True,lowercase=False),
    TfidfTransformer(norm = 'l2',sublinear_tf = True),
    OneVsRestClassifier(LinearSVC(penalty="l2",loss="squared_hinge",tol=1,random_state=0,max_iter=1000,C = 1)))

classifier.fit(X_train, Y_train)
# Out:
# Pipeline(memory=None,
#      steps=[('countvectorizer', CountVectorizer(analyzer='word', binary=True, decode_error='strict',
#         dtype=<class 'numpy.int64'>, encoding='utf-8', input='content',
#         lowercase=False, max_df=1.0, max_features=None, min_df=1,
#         ngram_range=(1, 3), preprocessor=None, stop_words=None,
#   ...0,
#      multi_class='ovr', penalty='l2', random_state=0, tol=1, verbose=0),
#           n_jobs=None))])

# %%
global X, Y, mlb, distinct_tags

predicted = classifier.predict(X_train)
print(Y_train.shape)
print(predicted.shape)


# print(Y_validation[int(Y_validation.shape[0]/2),:])
Y_validation[int(Y_validation.shape[0]/2),:] =  1
Y_train[int(Y_train.shape[0]/2),:] =  1
# print(Y_validation[int(Y_validation.shape[0]/2),:])

y_labels_predicted = mlb.inverse_transform(predicted)
y_labels_actual = mlb.inverse_transform(Y_train)

print("On Train data")

print("hamming_loss: ",hamming_loss(Y_train,predicted))
print("recall_score: ",recall_score(Y_train,predicted,average = 'weighted'))
print("precision_score: ",precision_score(Y_train,predicted,average = 'weighted'))
print("f1_score: ",f1_score(Y_train,predicted,average = 'weighted'))
print("roc_auc_score: ",roc_auc_score(Y_train,predicted,average = 'weighted'))
print()
print()

# print("Actual vs Predicted")
# for item, labels in zip(y_labels_actual, y_labels_predicted):
#         print('{0} => {1}'.format(item, ', '.join(labels)))

# print()
# print()

labels_list = mlb.classes_
roc_auc_list = []
for col_index in range(Y_train.shape[1]):
    roc_auc_list.append(roc_auc_score(Y_train[:,col_index],predicted[:,col_index]))

plt.figure(figsize=(10, 15), dpi=100)
plt.barh(labels_list,roc_auc_list, align='center', alpha=0.5)
plt.show()

print("On Validation data")

predicted = classifier.predict(X_validation)
y_labels_predicted = mlb.inverse_transform(predicted)
y_labels_actual = mlb.inverse_transform(Y_validation)

# Y_validation[int(Y_validation.shape[0]/2),:] =  1

print("hamming_loss: ",hamming_loss(Y_validation,predicted))
print("recall_score: ",recall_score(Y_validation,predicted,average = 'weighted'))
print("precision_score: ",precision_score(Y_validation,predicted,average = 'weighted'))
print("f1_score: ",f1_score(Y_validation,predicted,average = 'weighted'))
print("roc_auc_score: ",roc_auc_score(Y_validation,predicted,average = 'weighted'))
print()
print()
print("Actual vs Predicted")

################################################################################

metrics_list = []
recall_list = []
precision_list = []
roc_auc_list = []
f1_score_list = []

classes_list = mlb.classes_
    
for col_index in range(Y_validation.shape[1]):
    recall_list.append(recall_score(Y_validation[:,col_index],predicted[:,col_index]))
    
for col_index in range(Y_validation.shape[1]):
    precision_list.append(precision_score(Y_validation[:,col_index],predicted[:,col_index]))
    
for col_index in range(Y_validation.shape[1]):
    f1_score_list.append(f1_score(Y_validation[:,col_index],predicted[:,col_index]))
    
for col_index in range(Y_validation.shape[1]):
    roc_auc_list.append(roc_auc_score(Y_validation[:,col_index],predicted[:,col_index]))

metrics_list = [mlb,classes_list,recall_list,precision_list,f1_score_list,roc_auc_list,Y_validation,predicted]

with open('Linear_SVC_CodeChef', 'wb') as fp:
    pickle.dump(metrics_list, fp)

################################################################################

for item, labels in zip(y_labels_actual, y_labels_predicted):
        print('{0} => {1}'.format(item, ', '.join(labels)))

labels_list = mlb.classes_
roc_auc_list = []
for col_index in range(Y_validation.shape[1]):
    roc_auc_list.append(roc_auc_score(Y_validation[:,col_index],predicted[:,col_index]))

plt.figure(figsize=(10, 15), dpi=100)
plt.barh(labels_list,roc_auc_list, align='center', alpha=0.5)
plt.show()
# Out:
# (23456, 77)
# (23456, 77)
# On Train data
# hamming_loss:  7.751457273967505e-05
# recall_score:  0.9959178808736331
# precision_score:  0.9999102432077056
# f1_score:  0.9978781820658669
# roc_auc_score:  0.9979552798210974
# On Validation data
# hamming_loss:  0.0035900320688860934
# recall_score:  0.8169366364935684
# precision_score:  0.9869656689791306
# f1_score:  0.8877612732179232
# /home/prakashjha/.local/lib/python3.6/site-packages/sklearn/metrics/classification.py:1143: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples.
#   'precision', 'predicted', average, warn_for)
# /home/prakashjha/.local/lib/python3.6/site-packages/sklearn/metrics/classification.py:1143: UndefinedMetricWarning: F-score is ill-defined and being set to 0.0 in labels with no predicted samples.
#   'precision', 'predicted', average, warn_for)
# roc_auc_score:  0.9081184551966692
#
#
# Actual vs Predicted
# /home/prakashjha/.local/lib/python3.6/site-packages/sklearn/metrics/classification.py:1143: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples.
#   'precision', 'predicted', average, warn_for)
# /home/prakashjha/.local/lib/python3.6/site-packages/sklearn/metrics/classification.py:1143: UndefinedMetricWarning: F-score is ill-defined and being set to 0.0 due to no predicted samples.
#   'precision', 'predicted', average, warn_for)
# ('simulation',) => simulation
# ('hard',) => hard
# ('tree',) =>
# ('gcd',) => gcd
# ('strings',) => strings
# ('tree',) => tree
# ('tree',) => tree
# ('simulation',) => simulation
# ('greedy',) =>
# ('tree',) => tree
# ('maths',) => maths
# ('strings',) => strings
# ('greedy',) =>
# ('prime', 'segment', 'tree') => prime, segment, tree
# ('dp',) => dp
# ('deque',) => deque
# ('gcd',) => gcd
# ('hard',) => hard
# ('greedy', 'heap', 'multiset') => greedy, heap, multiset
# ('gcd',) => gcd
# ('map', 'sorting') => map, sorting
# ('basic', 'pattern', 'stack') =>
# ('dynamic',) => dynamic
# ('algebra',) => algebra
# ('bfs', 'dijkstra') => bfs, dijkstra
# ('combinatorics',) => combinatorics
# ('map', 'sorting') => map, sorting
# ('gcd',) => gcd
# ('deque',) => deque
# ('simulation',) => simulation
# ('stack',) => stack
# ('game', 'theory') => game, theory
# ('bfs', 'dijkstra') => bfs, dijkstra
# ('dp',) =>
# ('tree',) => tree
# ('dp',) =>
# ('combinatorics', 'greedy') =>
# ('gcd',) => gcd
# ('dynamic',) =>
# ('dp',) => dp
# ('basic',) => basic
# ('sorting',) => sorting
# ('greedy',) => greedy
# ('dp',) =>
# ('gcd',) => gcd
# ('basic', 'pattern', 'stack') =>
# ('algebra', 'series') => algebra, series
# ('gcd',) => gcd
# ('bfs', 'dijkstra') => bfs, dijkstra
# ('number', 'theory') => number, theory
# ('algebra',) => algebra
# ('dp',) => dp
# ('strings',) => strings
# ('greedy',) => greedy
# ('dp',) => dp
# ('combinatorics',) => combinatorics
# ('implementation',) =>
# ('gcd',) => gcd
# ('tree',) => tree
# ('binarysearch', 'fibonacci', 'hashing') => binarysearch, fibonacci, hashing
# ('simulation',) => simulation
# ('map', 'sorting') => map, sorting
# ('greedy', 'heap', 'multiset') => greedy, heap, multiset
# ('dp',) => dp
# ('sorting',) => sorting
# ('simulation',) => simulation
# ('segment', 'tree') => segment, tree
# ('stack',) => stack
# ('gcd',) => gcd
# ('simulation',) => simulation
# ('adhoc',) => adhoc
# ('maths',) =>
# ('simulation', 'sorting') => simulation, sorting
# ('gcd',) => gcd
# ('combinatorics',) => combinatorics
# ('hard',) => hard
# ('number', 'theory') => number, theory
# ('tree',) => tree
# ('dynamic',) => dynamic
# ('dp',) => dp
# ('tree',) => tree
# ('hard',) => hard
# ('hard', 'suffix') => hard
# ('simulation',) => simulation
# ('strings',) => strings
# ('combinatorics',) => combinatorics
# ('digraph', 'graph') =>
# ('tree',) => tree
# ('game', 'theory') => game, theory
# ('bfs', 'dijkstra') => bfs, dijkstra
# ('deque',) => deque
# ('greedy',) => greedy
# ('basic', 'pattern', 'stack') => basic, pattern, stack
# ('greedy',) =>
# ('strings',) => strings
# ('maths',) => maths
# ('tree',) => tree
# ('combinatorics',) => combinatorics
# ('map', 'sorting') => map, sorting
# ('simulation',) => simulation
# ('basic',) => basic
# ('geometry', 'maths') => geometry, maths
# ('strings',) => strings
# ('geometry',) => geometry
# ('hard', 'hashing') => hard, hashing
# ('greedy',) => greedy
# ('graphs',) =>
# ('dynamic',) => dynamic
# ('hard',) => hard
# ('dp',) =>
# ('gcd',) => gcd
# ('algebra',) => algebra
# ('maths',) => maths
# ('expo', 'maths', 'matrix') => expo, matrix
# ('binarysearch', 'fibonacci', 'hashing') => binarysearch, fibonacci, hashing
# ('gcd',) => gcd
# ('number', 'theory') => number, theory
# ('bfs', 'dijkstra') => bfs, dijkstra
# ('expo', 'matrix') =>
# ('map', 'sorting') => map, sorting
# ('hard',) => hard
# ('tree',) => tree
# ('segment', 'tree') => segment, tree
# ('maths',) =>
# ('hard',) => hard
# ('maths',) => maths
# ('dp',) => dp
# ('maths',) =>
# ('dynamic',) =>
# ('maths',) => maths
# ('basic',) => basic
# ('simulation',) => simulation
# ('dp',) => dp
# ('dp',) => dp
# ('gcd',) => gcd
# ('basic', 'graph') =>
# ('kruskal',) => kruskal
# ('combinatorics', 'greedy') =>
# ('dp', 'dynamic') => dynamic
# ('hard', 'segment', 'tree') => hard
# ('tree',) => tree
# ('disjoint', 'hard', 'segment', 'set', 'stack', 'suffix', 'tree', 'trees') => disjoint, hard, segment, set, stack, suffix, tree, trees
# ('expo', 'matrix', 'recurrence') => expo, matrix, recurrence
# ('dfs', 'sieve') => dfs, sieve
# ('greedy',) => greedy
# ('bfs', 'dijkstra') => bfs, dijkstra
# ('basic',) => basic
# ('greedy',) => greedy
# ('binarysearch', 'fibonacci', 'hashing') => binarysearch, fibonacci, hashing
# ('greedy',) => greedy
# ('dfs', 'sieve') => dfs, sieve
# ('dynamic',) => dynamic
# ('dp',) => dp
# ('greedy', 'heap', 'multiset') => greedy, heap, multiset
# ('dp',) => dp
# ('algebra',) => algebra
# ('adhoc',) =>
# ('expo', 'maths', 'matrix') => expo, matrix, recurrence
# ('maths',) => maths
# ('greedy',) => greedy
# ('simulation',) => simulation
# ('binarysearch', 'fibonacci', 'hashing') => binarysearch, fibonacci, hashing
# ('advanced', 'maths') => hard
# ('stack',) => stack
# ('dp', 'dynamic') => dp, dynamic
# ('simulation',) => simulation
# ('maths',) => maths
# ('basic',) => basic
# ('dynamic',) =>
# ('simulation', 'sorting') => simulation, sorting
# ('simulation',) => simulation
# ('greedy',) => greedy
# ('hard', 'suffix') => hard, suffix
# ('bfs', 'dijkstra') => bfs, dijkstra
# ('expo', 'matrix', 'recurrence') =>
# ('greedy', 'heap', 'multiset') => greedy, heap, multiset
# ('expo', 'matrix', 'recurrence') =>
# ('dp',) => dp
# ('fenwick', 'inversions') => segment
# ('greedy',) => greedy
# ('maths',) => maths
# ('sorting',) => sorting
# ('gcd',) => gcd
# ('dp',) => dp
# ('expo', 'matrix', 'recurrence') => expo, matrix, recurrence
# ('gcd',) =>
# ('greedy',) => greedy
# ('combinatorics',) => combinatorics
# ('greedy',) => greedy
# ('greedy',) => greedy
# ('geometry',) => geometry
# ('dp',) =>
# ('basic',) => basic
# ('strings',) => strings
# ('map', 'sorting') => map, sorting
# ('maths',) => maths
# ('segment', 'tree') => segment, tree
# ('simulation', 'sorting') =>
# ('maths',) => maths
# ('bruteforce',) => bruteforce
# ('segment', 'tree') => segment, tree
# ('greedy',) => greedy
# ('maths',) => maths
# ('gcd',) => gcd
# ('simulation',) => simulation
# ('stack',) => stack
# ('tree',) => tree
# ('dp',) => dp
# ('combinatorics',) =>
# ('algebra',) => algebra
# ('basic',) => basic
# ('simulation',) => simulation
# ('dynamic',) =>
# ('greedy',) => greedy
# ('segment', 'tree') => segment, tree
# ('dp',) => dp
# ('game', 'theory') => game, theory
# ('basic',) => basic
# ('greedy',) =>
# ('sorting',) => sorting
# ('combinatorics', 'counting', 'game', 'theory') =>
# ('simulation',) => simulation
# ('hard',) => hard
# ('greedy',) =>
# ('combinatorics',) => combinatorics
# ('maths',) => maths
# ('basic',) => basic
# ('greedy',) => greedy
# ('bitwise', 'segment', 'tree') => bitwise, segment, tree
# ('strings',) => strings
# ('maths',) => maths
# ('backtracking',) => backtracking
# ('dp',) => dp
# ('backtracking',) => backtracking
# ('tree',) => tree
# ('combinatorics', 'counting', 'game', 'theory') => combinatorics, counting, game, theory
# ('expo', 'matrix', 'recurrence') => expo, matrix, recurrence
# ('geometry', 'maths') => geometry, maths
# ('game', 'theory') => game, theory
# ('hard',) => hard
# ('greedy',) => greedy
# ('algebra',) => algebra
# ('map', 'sorting') => map, sorting
# ('geometry',) => geometry
# ('dfs', 'sieve') => dfs, sieve
# ('dp',) => dp
# ('dp',) => dp
# ('tree',) => tree
# ('tree',) => tree
# ('combinatorics', 'divide', 'fft', 'hard') => combinatorics, divide, fft, hard
# ('sorting',) => sorting
# ('greedy', 'heap', 'multiset') => greedy
# ('expo', 'maths', 'matrix') => expo, matrix
# ('dp',) => dp
# ('dp',) => dp
# ('dynamic',) => dynamic
# ('greedy',) => greedy
# ('dynamic',) =>
# ('gcd',) => gcd
# ('gcd',) => gcd
# ('simulation',) => simulation
# ('deque',) =>
# ('simulation',) => simulation
# ('expo', 'matrix', 'recurrence') => expo, matrix
# ('kruskal',) => kruskal
# ('segment', 'tree') => segment, tree
# ('algebra',) =>
# ('basic', 'graph') => graph
# ('simulation',) => simulation
# ('kruskal',) => kruskal
# ('bfs', 'dijkstra') => bfs, dijkstra
# ('gcd',) => gcd
# ('prime', 'segment', 'tree') => prime, segment, tree
# ('hard',) => hard
# ('tree',) => tree
# ('gcd',) => gcd
# ('dp',) => dp
# ('dp',) => dp
# ('digraph', 'graph') => digraph, graph
# ('simulation',) => simulation
# ('dp',) => dp
# ('bfs', 'dijkstra') => bfs, dijkstra
# ('basic', 'graph') =>
# ('hard', 'suffix') => hard
# ('expo', 'matrix', 'recurrence') => expo, matrix, recurrence
# ('combinatorics', 'greedy') => combinatorics, greedy
# ('dp',) => dp
# ('simulation',) => simulation
# ('map', 'sorting') => map, sorting
# ('implementation',) => greedy
# ('greedy',) => greedy
# ('basic',) => basic
# ('strings',) => strings
# ('dp',) => dp
# ('greedy',) => greedy
# ('strings',) => strings
# ('basic',) => basic
# ('strings',) => strings
# ('maths',) => maths
# ('hard', 'suffix') => hard, suffix
# ('greedy',) => greedy
# ('combinatorics',) => combinatorics
# ('dfs', 'sieve') => dfs, sieve
# ('tree',) => tree
# ('basic',) => basic
# ('combinatorics',) => combinatorics
# ('bruteforce',) => bruteforce
# ('kruskal',) => kruskal
# ('sorting',) =>
# ('basic',) => basic
# ('simulation',) => simulation
# ('simulation',) => simulation
# ('digraph', 'graph') =>
# ('hard',) => hard
# ('tree',) => tree
# ('greedy',) => greedy
# ('dp',) => greedy
# ('gcd',) => gcd
# ('algebra',) =>
# ('dp',) =>
# ('geometry',) => geometry
# ('strings',) => strings
# ('simulation',) => simulation
# ('backtracking',) =>
# ('digraph', 'graph') => digraph, graph
# ('simulation',) => simulation
# ('tree',) =>
# ('sorting',) => sorting
# ('bruteforce',) =>
# ('adhoc',) => adhoc
# ('adhoc',) => adhoc
# ('tree',) => tree
# ('combinatorics',) => combinatorics
# ('gcd',) => gcd, greedy
# ('strings',) => strings
# ('kruskal',) => kruskal
# ('simulation',) => simulation
# ('gcd',) =>
# ('gcd',) => gcd
# ('bipartite', 'geometry', 'hard', 'maxflow', 'set') => bipartite, geometry, hard, maxflow, set
# ('greedy',) => greedy
# ('greedy',) => greedy
# ('dp',) =>
# ('dynamic',) =>
# ('advanced', 'maths') => hard
# ('simulation',) => simulation
# ('backtracking',) => backtracking
# ('gcd',) => gcd
# ('simulation',) => simulation
# ('tree',) => tree
# ('disjoint', 'hard', 'segment', 'set', 'stack', 'suffix', 'tree', 'trees') => disjoint, hard, segment, set, stack, suffix, tree, trees
# ('expo', 'maths', 'matrix') => expo, matrix
# ('implementation',) => implementation
# ('hard',) => hard
# ('combinatorics',) => combinatorics
# ('backtracking', 'enumeration') => backtracking, enumeration
# ('digraph', 'graph') => digraph, graph
# ('kruskal',) => kruskal
# ('dp',) => dp
# ('simulation',) => simulation
# ('strings',) => strings
# ('fft', 'hard', 'maths') => fft, hard, maths
# ('simulation',) => simulation
# ('greedy',) => greedy
# ('tree',) => tree
# ('combinatorics',) => combinatorics
# ('greedy',) => greedy
# ('prime', 'segment', 'tree') => prime, segment, tree
# ('tree',) => tree
# ('dfs', 'sieve') =>
# ('strings',) => strings
# ('sorting',) => sorting
# ('dp',) => dp
# ('simulation',) => simulation
# ('tree',) => tree
# ('strings',) => strings
# ('greedy',) => greedy
# ('sorting',) => sorting
# ('map', 'sorting') => sorting
# ('bitwise', 'segment', 'tree') => bitwise, segment, tree
# ('euler', 'graph') => euler, graph
# ('greedy',) => greedy
# ('graph', 'hard') => graph, hard
# ('gcd',) => gcd
# ('dp',) => dp
# ('maths',) => maths
# ('disjoint', 'hard', 'segment', 'set', 'stack', 'suffix', 'tree', 'trees') => hard
# ('gcd',) => gcd
# ('simulation',) => simulation
# ('simulation',) => simulation
# ('maths',) => maths
# ('dp',) => dp
# ('geometry',) => geometry
# ('backtracking',) => backtracking
# ('gcd',) => gcd
# ('dp',) => dp
# ('simulation',) => simulation
# ('binarysearch', 'fibonacci', 'hashing') => binarysearch, fibonacci, hashing
# ('digraph', 'graph') => digraph, graph
# ('greedy',) =>
# ('gcd',) => gcd
# ('algebra',) =>
# ('maths',) => maths
# ('maths',) => maths
# ('dynamic',) => dynamic
# ('gcd',) => gcd
# ('tree',) => tree
# ('combinatorics',) => combinatorics
# ('basic', 'graph') => basic, graph
# ('sorting',) => sorting
# ('dp', 'dynamic') => dp, dynamic
# ('sorting',) => sorting
# ('gcd',) => gcd
# ('game', 'theory') => game, theory
# ('basic',) => basic
# ('tree',) => tree
# ('strings',) => strings
# ('greedy',) => greedy
# ('dp',) =>
# ('maths',) => maths
# ('maths',) => maths
# ('hard',) => hard
# ('hard',) => hard
# ('basic',) => basic
# ('tree',) => tree
# ('hard',) => hard
# ('sorting',) => sorting
# ('bruteforce',) =>
# ('greedy',) => greedy
# ('combinatorics', 'greedy') => expo, greedy, matrix
# ('simulation',) => simulation
# ('gcd',) => gcd
# ('simulation',) => simulation
# ('gcd',) => gcd
# ('map', 'sorting') => map, sorting
# ('graph', 'hard') => graph, hard
# ('hard',) => hard
# ('expo', 'maths', 'matrix') => expo, maths, matrix
# ('greedy', 'heap', 'multiset') =>
# ('dfs', 'sieve') =>
# ('simulation',) => simulation
# ('map', 'sorting') =>
# ('simulation',) => simulation
# ('greedy',) => greedy
# ('greedy',) => greedy
# ('dp',) =>
# ('gcd',) => gcd
# ('deque',) => deque
# ('binarysearch', 'fibonacci', 'hashing') => binarysearch, fibonacci, hashing
# ('graph',) => graph
# ('algebra',) => algebra
# ('dp',) => dp
# ('simulation',) => simulation
# ('simulation', 'sorting') =>
# ('greedy',) => greedy
# ('tree',) =>
# ('greedy',) => greedy
# ('simulation',) => simulation
# ('sorting',) => sorting
# ('gcd',) => gcd
# ('implementation',) => implementation
# ('gcd',) =>
# ('basic',) => basic
# ('binarysearch', 'fibonacci', 'hashing') => binarysearch, fibonacci, hashing
# ('simulation',) => simulation
# ('digraph', 'graph') => digraph, graph
# ('number', 'theory') => number, theory
# ('bfs', 'dijkstra') => bfs, dijkstra
# ('greedy',) => greedy
# ('geometry', 'maths') =>
# ('bitwise',) =>
# ('dynamic',) => dynamic
# ('geometry',) => geometry
# ('strings',) => strings
# ('dynamic',) => dynamic
# ('strings',) => strings
# ('gcd',) => gcd
# ('combinatorics',) => combinatorics
# ('strings',) => strings
# ('simulation',) => simulation
# ('gcd',) =>
# ('bruteforce',) => bruteforce
# ('combinatorics',) =>
# ('backtracking',) => backtracking
# ('map', 'sorting') => map, sorting
# ('gcd',) => gcd
# ('simulation',) => simulation
# ('dp',) => dp
# ('simulation',) => simulation
# ('greedy',) => greedy
# ('combinatorics', 'counting', 'game', 'theory') =>
# ('combinatorics', 'greedy') => combinatorics, greedy
# ('algebra',) => algebra
# ('probability', 'sorting') =>
# ('strings',) => strings
# ('prime', 'segment', 'tree') => prime, segment, tree
# ('strings',) => strings
# ('hard',) => hard
# ('game', 'theory') => game, theory
# ('tree',) => tree
# ('tree',) => tree
# ('greedy', 'heap', 'multiset') => greedy, heap, multiset
# ('gcd',) => gcd
# ('tree',) => tree
# ('simulation',) => simulation
# ('basic',) => basic
# ('strings',) => strings
# ('greedy',) => greedy
# ('fenwick', 'inversions') => segment, tree
# ('tree',) =>
# ('gcd',) => gcd
# ('algebra',) =>
# ('gcd',) => gcd
# ('number', 'theory') => gcd
# ('digraph', 'graph') =>
# ('dp',) => dp
# ('deque',) => deque
# ('expo', 'maths', 'matrix') => expo, maths, matrix
# ('expo', 'matrix', 'recurrence') => expo, matrix, recurrence
# ('prime', 'segment', 'tree') => segment, tree
# ('combinatorics', 'hard') => combinatorics, hard
# ('greedy',) => greedy
# ('maths',) => maths
# ('kruskal',) => kruskal
# ('greedy',) => greedy
# ('tree',) => tree
# ('simulation',) => simulation
# ('gcd',) => gcd
# ('bfs', 'dijkstra') => bfs, dijkstra
# ('kruskal',) => kruskal
# ('gcd',) => gcd
# ('dp',) =>
# ('greedy',) => greedy
# ('dynamic',) => dynamic
# ('strings',) => strings
# ('dp',) => dp
# ('gcd',) => gcd
# ('greedy',) => greedy
# ('dp',) =>
# ('gcd',) => gcd
# ('basic',) => basic
# ('simulation',) => simulation
# ('gcd',) => gcd
# ('strings',) => strings
# ('dp',) => dp
# ('sorting',) => sorting
# ('dp',) => dp
# ('gcd',) => gcd
# ('dp',) => dp
# ('greedy',) => greedy
# ('simulation',) => simulation
# ('euler', 'graph') =>
# ('stack',) =>
# ('basic', 'pattern', 'stack') => stack
# ('dp',) => dp
# ('implementation',) =>
# ('simulation',) => simulation
# ('bfs', 'dijkstra') => bfs, dijkstra
# ('simulation',) => simulation
# ('probability', 'sorting') => probability, sorting
# ('simulation',) => simulation
# ('combinatorics', 'counting', 'game', 'theory') => combinatorics
# ('hard', 'tries') => hard
# ('strings',) => strings
# ('probability', 'sorting') =>
# ('binarysearch', 'fibonacci', 'hashing') => binarysearch, fibonacci, hashing
# ('digraph', 'graph') => digraph, graph
# ('dp',) => dp
# ('binary', 'search') => binary, search
# ('simulation',) => simulation
# ('bfs', 'dijkstra') => bfs, dijkstra
# ('greedy',) => greedy
# ('dp',) => dp
# ('algebra',) =>
# ('binarysearch', 'fibonacci', 'hashing') => binarysearch, fibonacci, hashing
# ('simulation',) => simulation
# ('tree',) => tree
# ('binarysearch', 'fibonacci', 'hashing') => binarysearch, fibonacci, hashing
# ('binary', 'search') => binary, search
# ('greedy',) =>
# ('gcd',) => gcd
# ('sorting',) => sorting
# ('dp',) => dp
# ('simulation',) => simulation
# ('gcd',) => gcd
# ('geometry',) => geometry
# ('dynamic',) => dynamic
# ('dp',) => dp
# ('greedy', 'heap', 'multiset') => greedy, heap, multiset
# ('combinatorics',) => combinatorics
# ('combinatorics',) => combinatorics
# ('basic',) => basic
# ('simulation',) => simulation
# ('dp',) => dp, greedy
# ('simulation',) => simulation
# ('tree',) => tree
# ('fft', 'hard', 'maths') => fft, hard, maths
# ('dp',) => dp
# ('game',) => game
# ('tree',) => tree
# ('dynamic',) => dynamic
# ('bfs', 'graph') =>
# ('adhoc',) =>
# ('gcd',) => gcd
# ('adhoc',) => adhoc
# ('binarysearch', 'fibonacci', 'hashing') => binarysearch, fibonacci, hashing
# ('disjoint', 'hard', 'segment', 'set', 'stack', 'suffix', 'tree', 'trees') => disjoint, hard, segment, set, stack, suffix, tree, trees
# ('fft', 'hard', 'maths') => fft, hard, maths
# ('dynamic',) => dynamic
# ('expo', 'matrix', 'recurrence') => expo, matrix
# ('bfs', 'dijkstra') => bfs, dijkstra
# ('sorting',) => sorting
# ('digraph', 'graph') => digraph, graph
# ('bfs', 'dijkstra') => bfs, dijkstra
# ('prime', 'segment', 'tree') =>
# ('gcd',) => gcd
# ('simulation',) => simulation
# ('sorting',) => sorting
# ('gcd',) => gcd
# ('bfs', 'dijkstra') => bfs, dijkstra
# ('binarysearch', 'fibonacci', 'hashing') => binarysearch, fibonacci, hashing
# ('gcd',) => gcd
# ('dynamic',) =>
# ('greedy',) => greedy
# ('gcd',) => gcd
# ('dfs', 'sieve') => dfs, sieve
# ('strings',) => strings
# ('dp',) => dp
# ('gcd',) => gcd
# ('game',) => game
# ('gcd',) => gcd
# ('dynamic',) => dynamic
# ('segment', 'tree') => segment, tree
# ('expo', 'matrix', 'recurrence') =>
# ('map', 'sorting') => map, sorting
# ('maths',) =>
# ('combinatorics', 'counting', 'game', 'theory') => combinatorics, theory
# ('greedy',) => greedy
# ('deque',) =>
# ('dynamic',) => dynamic
# ('graph',) =>
# ('greedy', 'heap', 'multiset') => greedy, heap, multiset
# ('combinatorics',) => combinatorics
# ('tree',) => tree
# ('combinatorics',) => segment
# ('tree',) =>
# ('greedy',) => greedy
# ('greedy',) => greedy
# ('bfs', 'graph') => bfs, graph
# ('gcd',) => gcd
# ('prime', 'segment', 'tree') => prime, segment, tree
# ('probability', 'sorting') =>
# ('bfs', 'dijkstra') => bfs, dijkstra
# ('combinatorics', 'hard') => combinatorics, hard
# ('dp',) => dp
# ('binarysearch', 'fibonacci', 'hashing') => binarysearch, fibonacci, hashing
# ('bfs', 'dijkstra') => bfs, dijkstra
# ('dp',) => dp
# ('combinatorics', 'counting', 'game', 'theory') =>
# ('gcd',) => gcd
# ('greedy',) => greedy
# ('expo', 'matrix', 'recurrence') => expo, matrix, recurrence
# ('maths',) => maths
# ('hard', 'segment', 'tree') => hard, tree
# ('dp',) => dp
# ('greedy',) => greedy
# ('dp',) => dp
# ('deque',) => deque
# ('geometry',) =>
# ('binarysearch', 'fibonacci', 'hashing') => binarysearch, fibonacci, hashing
# ('algebra',) => algebra
# ('constructive', 'greedy', 'implementation') => greedy
# ('basic',) => basic
# ('stack',) => stack
# ('tree',) => tree
# ('algebra',) => algebra
# ('greedy', 'hard', 'pointers', 'segment', 'tree') =>
# ('simulation', 'sorting') => simulation, sorting
# ('dp',) => dp
# ('gcd',) => greedy
# ('bfs', 'graph') => bfs
# ('graph', 'hard') => graph, hard
# ('greedy',) => greedy
# ('gcd',) => gcd
# ('dynamic',) => dynamic
# ('simulation',) => simulation
# ('graph', 'hard') => graph, hard
# ('greedy',) =>
# ('geometry',) => geometry, maths
# ('game', 'theory') => game, theory
# ('gcd',) => gcd
# ('dynamic',) => dynamic
# ('greedy',) => greedy
# ('sorting',) => greedy
# ('tree',) => tree
# ('gcd',) => gcd
# ('simulation', 'sorting') =>
# ('dp',) => dp
# ('strings',) => strings
# ('tree',) => tree
# ('simulation', 'sorting') => simulation, sorting
# ('basic',) => basic
# ('algebra',) =>
# ('combinatorics', 'counting', 'game', 'theory') => combinatorics, counting, game, theory
# ('gcd',) => gcd
# ('algorithm', 'hard') => algorithm, hard
# ('stack',) => stack
# ('bfs', 'dijkstra') => bfs, dijkstra
# ('hard',) => hard
# ('greedy',) =>
# ('simulation',) => simulation
# ('gcd',) => gcd
# ('tree',) => tree
# ('greedy',) => greedy
# ('simulation',) => simulation
# ('bfs', 'dijkstra') => bfs, dijkstra
# ('binarysearch', 'fibonacci', 'hashing') => binarysearch, fibonacci, hashing
# ('dp',) => dp
# ('dp',) => dp
# ('simulation',) => simulation
# ('bfs', 'dijkstra') => bfs, dijkstra
# ('greedy',) => greedy
# ('binarysearch', 'fibonacci', 'hashing') => binarysearch, fibonacci, hashing
# ('graphs',) => graphs
# ('dp',) =>
# ('combinatorics',) => combinatorics
# ('gcd',) => gcd
# ('strings',) => strings
# ('greedy',) => greedy
# ('greedy',) => greedy
# ('sorting',) => sorting
# ('strings',) => strings
# ('euler', 'graph') =>
# ('combinatorics',) => combinatorics
# ('dynamic',) =>
# ('greedy',) => gcd
# ('segment', 'tree') => segment, tree
# ('greedy',) => greedy
# ('tree',) => tree
# ('dynamic',) => dynamic
# ('combinatorics',) => combinatorics
# ('simulation',) => simulation
# ('maths',) => maths
# ('greedy',) => greedy
# ('dp',) => dp
# ('combinatorics',) => combinatorics
# ('map', 'sorting') => sorting
# ('hard',) => hard
# ('greedy',) => greedy
# ('probability', 'sorting') => probability, sorting
# ('algebra',) => algebra
# ('geometry',) => geometry
# ('combinatorics',) => combinatorics
# ('kruskal',) => kruskal
# ('basic',) => basic
# ('kruskal',) => kruskal
# ('simulation',) => simulation
# ('basic',) => basic
# ('strings',) => strings
# ('binarysearch', 'fibonacci', 'hashing') => binarysearch, fibonacci, hashing
# ('segment', 'tree') => segment, tree
# ('dp',) => dp
# ('algebra',) => algebra
# ('tree',) => tree
# ('game',) => game
# ('simulation',) => simulation
# ('simulation',) => simulation
# ('greedy',) => greedy
# ('simulation',) => simulation
# ('map', 'sorting') => map, sorting
# ('basic',) =>
# ('number', 'theory') => number, theory
# ('bruteforce',) =>
# ('binarysearch', 'fibonacci', 'hashing') => binarysearch, fibonacci, hashing
# ('fft', 'hard', 'maths') => fft, hard, maths
# ('basic', 'pattern', 'stack') =>
# ('gcd',) => gcd
# ('hard', 'number', 'theory') => hard, segment
# ('binarysearch', 'fibonacci', 'hashing') => binarysearch, fibonacci, hashing
# ('gcd',) => gcd
# ('game', 'theory') => game, theory
# ('backtracking',) => backtracking
# ('digraph', 'graph') => digraph, graph
# ('greedy',) =>
# ('maths',) => maths
# ('binary', 'search') => binary, search
# ('tree',) => tree
# ('dp',) => dp
# ('expo', 'maths', 'matrix') => expo, matrix
# ('gcd',) => gcd
# ('gcd',) => gcd
# ('backtracking',) => backtracking
# ('maths',) => maths
# ('simulation',) => simulation
# ('dp',) => dp
# ('dfs', 'sieve') => dfs, sieve
# ('simulation',) => simulation
# ('segment', 'tree') => segment, tree
# ('greedy',) => greedy
# ('greedy',) => greedy
# ('simulation', 'sorting') => simulation, sorting
# ('simulation',) => simulation
# ('geometry',) => geometry
# ('gcd',) => gcd
# ('gcd',) => gcd
# ('expo', 'matrix', 'recurrence') => expo, matrix, recurrence
# ('number', 'theory') => number, theory
# ('simulation',) => simulation
# ('binarysearch', 'fibonacci', 'hashing') => binarysearch, fibonacci, hashing
# ('digraph', 'graph') =>
# ('dp',) => dp
# ('dp',) => dp
# ('dynamic',) => dynamic
# ('game', 'theory') => game, theory
# ('dp',) => dp
# ('dp',) => dp
# ('simulation',) => simulation
# ('maths',) => maths
# ('greedy', 'heap', 'multiset') => greedy, heap, multiset
# ('gcd',) => gcd
# ('greedy', 'heap', 'multiset') => greedy, heap, multiset
# ('adhoc',) => adhoc
# ('hard', 'hashing') =>
# ('sorting',) =>
# ('greedy',) => greedy
# ('bfs', 'dijkstra') => bfs, dijkstra
# ('strings',) => strings
# ('number', 'theory') => number, theory
# ('tree',) => tree
# ('greedy',) => greedy
# ('greedy',) => greedy
# ('dynamic',) => dynamic
# ('simulation',) => simulation
# ('tree',) => tree
# ('basic',) => basic
# ('expo', 'matrix', 'recurrence') => expo, matrix, recurrence
# ('strings',) => strings
# ('map', 'sorting') => map, sorting
# ('basic', 'pattern', 'stack') =>
# ('stack',) => stack
# ('bfs', 'dijkstra') => bfs, dijkstra
# ('strings',) => strings
# ('simulation',) => simulation
# ('simulation',) => simulation
# ('basic', 'pattern', 'stack') => basic, pattern, stack
# ('maths',) => maths
# ('algebra',) => algebra
# ('expo', 'maths', 'matrix') => expo, matrix
# ('bitwise', 'segment', 'tree') => segment, tree
# ('hard', 'number', 'theory') => hard, number, theory
# ('adhoc',) => adhoc
# ('simulation',) => simulation
# ('maths',) => maths
# ('sorting',) => sorting
# ('constructive', 'greedy', 'implementation') =>
# ('gcd',) => gcd
# ('dp',) => dp
# ('combinatorics',) => combinatorics
# ('greedy',) => greedy
# ('strings',) => strings
# ('dp',) => dp
# ('tree',) => tree
# ('combinatorics', 'divide', 'fft', 'hard') => fft, hard, maths
# ('graph', 'hard') => graph, hard
# ('gcd',) => gcd
# ('expo', 'maths', 'matrix') => expo, maths, matrix
# ('simulation',) => simulation
# ('basic',) => basic
# ('strings',) => strings
# ('geometry',) => geometry
# ('combinatorics',) =>
# ('gcd',) => gcd
# ('strings',) => strings
# ('greedy',) => greedy
# ('algebra',) => algebra
# ('greedy',) => greedy
# ('stack',) => stack
# ('fft', 'hard', 'maths') => fft, hard, maths
# ('gcd',) => gcd
# ('dp',) =>
# ('gcd',) => gcd
# ('simulation',) => simulation
# ('greedy',) => greedy
# ('number', 'theory') => number, theory
# ('basic',) => basic
# ('basic',) => basic
# ('maths',) => maths
# ('strings',) => strings
# ('combinatorics', 'counting', 'game', 'theory') => combinatorics, counting, game, theory
# ('dp',) => dp
# ('simulation',) => simulation
# ('stack',) => stack
# ('hard', 'tree') => hard, tree
# ('algebra',) => algebra
# ('algebra',) => algebra
# ('gcd',) => gcd
# ('stack',) => stack
# ('dp',) =>
# ('bfs', 'dijkstra') => bfs, dijkstra
# ('digraph', 'graph') => digraph, graph
# ('number', 'theory') => number, theory
# ('hard',) => hard
# ('strings',) => strings
# ('greedy',) => greedy
# ('basic',) => basic
# ('binarysearch', 'fibonacci', 'hashing') => binarysearch, fibonacci, hashing
# ('hard',) => hard
# ('simulation',) => simulation
# ('algebra',) => algebra
# ('fft', 'hard', 'maths') => fft, hard, maths
# ('basic', 'pattern', 'stack') =>
# ('dynamic',) =>
# ('simulation',) => simulation
# ('dp',) => dp
# ('maths',) => maths
# ('dynamic',) =>
# ('hard', 'number', 'theory') => hard
# ('tree',) =>
# ('greedy',) => greedy
# ('gcd',) =>
# ('dp',) => dp
# ('digraph', 'graph') =>
# ('bfs', 'dijkstra') => bfs, dijkstra
# ('algebra',) => algebra
# ('bfs', 'dijkstra') => bfs, dijkstra
# ('dynamic',) => dynamic
# ('bruteforce',) => bruteforce
# ('combinatorics',) => combinatorics
# ('segment', 'tree') => segment, tree
# ('expo', 'matrix', 'recurrence') => expo, matrix
# ('dp',) =>
# ('maths',) => maths
# ('backtracking',) =>
# ('dfs', 'sieve') => dfs, sieve
# ('basic',) => basic
# ('hard',) => hard
# ('expo', 'matrix', 'recurrence') => expo, matrix, recurrence
# ('combinatorics',) => combinatorics
# ('backtracking',) => backtracking
# ('binarysearch', 'fibonacci', 'hashing') =>
# ('dp',) => dp
# ('simulation',) => simulation
# ('greedy', 'heap', 'multiset') =>
# ('gcd',) => gcd
# ('expo', 'matrix', 'recurrence') => expo, matrix
# ('sorting',) => sorting
# ('gcd',) => gcd
# ('geometry',) => geometry
# ('maths',) =>
# ('dp',) => dp
# ('strings',) => strings
# ('dp',) =>
# ('implementation',) => implementation
# ('constructive', 'greedy', 'implementation') =>
# ('dp', 'hard', 'memoization') =>
# ('binarysearch', 'fibonacci', 'hashing') => binarysearch, fibonacci, hashing
# ('greedy',) => greedy
# ('strings',) => strings
# ('bfs', 'dijkstra') => bfs, dijkstra
# ('dp',) => dp
# ('tree',) => tree
# ('gcd',) => gcd
# ('bitmasking', 'graph', 'hard') =>
# ('tree',) => tree
# ('greedy',) => greedy
# ('kruskal',) => kruskal
# ('dp',) => dp
# ('basic',) =>
# ('gcd',) => gcd
# ('gcd',) => gcd
# ('greedy',) => greedy
# ('geometry',) => geometry
# ('game', 'theory') => game, theory
# ('basic',) => basic
# ('gcd',) => gcd
# ('hard', 'tree') => hard, tree
# ('greedy', 'heap', 'multiset') => greedy, heap, multiset
# ('adhoc',) => adhoc
# ('maths',) => maths
# ('basic', 'graph') => basic, graph
# ('greedy',) => greedy
# ('adhoc',) => adhoc
# ('gcd',) => gcd
# ('basic',) => basic
# ('algebra',) => algebra
# ('simulation',) => simulation
# ('basic',) => basic
# ('combinatorics',) => combinatorics
# ('gcd',) => gcd
# ('probability', 'sorting') => probability, sorting
# ('dp',) =>
# ('map', 'sorting') => map, sorting
# ('combinatorics',) =>
# ('dp',) => dp
# ('strings',) => strings
# ('tree',) => tree
# ('gcd',) => gcd
# ('maths',) => maths
# ('bfs', 'dijkstra') =>
# ('gcd',) => gcd
# ('basic',) => basic
# ('hard', 'suffix') => hard, suffix
# ('dynamic',) => dynamic
# ('maths',) =>
# ('dynamic',) => dynamic
# ('algebra', 'hard') => algebra, hard
# ('greedy',) => greedy
# ('tree',) => tree
# ('simulation',) => simulation
# ('kruskal',) => kruskal
# ('greedy',) => greedy
# ('tree',) => tree
# ('strings',) => strings
# ('backtracking',) => backtracking
# ('dp',) => dp
# ('greedy',) => greedy
# ('binarysearch', 'fibonacci', 'hashing') => binarysearch, fibonacci, hashing
# ('segment', 'tree') => segment, tree
# ('algebra',) => algebra
# ('dynamic',) => dynamic
# ('map', 'sorting') => map, sorting
# ('sorting',) => sorting
# ('greedy',) => greedy
# ('greedy', 'heap', 'multiset') => greedy, heap, multiset
# ('combinatorics',) => combinatorics
# ('tree',) => tree
# ('simulation',) => simulation
# ('gcd',) =>
# ('maths',) => maths
# ('gcd',) => gcd
# ('greedy',) => greedy
# ('algebra',) => algebra
# ('simulation',) => simulation
# ('combinatorics',) => combinatorics
# ('dp',) => dp
# ('greedy',) => greedy
# ('maths',) => maths
# ('digraph', 'graph') =>
# ('number', 'theory') => number, theory
# ('greedy',) => greedy
# ('expo', 'matrix', 'recurrence') =>
# ('bfs', 'graph') => graph
# ('dp',) => dp
# ('expo', 'matrix', 'recurrence') => expo, matrix, recurrence
# ('basic', 'pattern', 'stack') =>
# ('kruskal',) => kruskal
# ('strings',) => strings
# ('simulation',) => simulation
# ('gcd',) => gcd
# ('gcd',) => gcd
# ('map', 'sorting') => map, sorting
# ('sorting',) => sorting
# ('strings',) => strings
# ('basic', 'pattern', 'stack') => basic, pattern, stack
# ('tree',) => tree
# ('algebra',) => algebra
# ('gcd',) => gcd
# ('simulation',) => simulation
# ('gcd',) => gcd
# ('greedy', 'heap', 'multiset') => greedy, heap, multiset
# ('implementation',) =>
# ('tree',) => tree
# ('backtracking', 'enumeration') => backtracking, enumeration
# ('gcd',) => gcd
# ('binarysearch', 'fibonacci', 'hashing') => binarysearch, fibonacci, hashing
# ('dynamic',) => dynamic
# ('greedy',) => greedy
# ('gcd',) =>
# ('greedy',) => greedy
# ('expo', 'maths', 'matrix') => expo, matrix
# ('constructive', 'greedy', 'implementation') =>
# ('strings',) => strings
# ('simulation',) => simulation
# ('simulation',) => simulation
# ('gcd',) => gcd
# ('greedy',) =>
# ('dp',) => dp
# ('geometry', 'maths') => geometry, maths
# ('expo', 'matrix', 'recurrence') => expo, matrix, recurrence
# ('kruskal',) => kruskal
# ('gcd',) => gcd
# ('simulation',) => simulation
# ('hard',) => hard
# ('geometry',) => geometry
# ('strings',) => strings
# ('combinatorics',) =>
# ('simulation',) => simulation
# ('gcd',) => gcd
# ('strings',) => strings
# ('dynamic',) =>
# ('strings',) => strings
# ('tree',) => tree
# ('dp',) => dp
# ('tree',) => tree
# ('gcd',) => gcd
# ('basic',) =>
# ('gcd',) => gcd
# ('greedy',) => greedy
# ('basic',) => basic
# ('maths',) => maths
# ('greedy',) =>
# ('expo', 'matrix') => expo, matrix
# ('dp',) => dp
# ('greedy', 'heap', 'multiset') => greedy, heap, multiset
# ('dynamic',) => combinatorics, dynamic
# ('expo', 'maths', 'matrix') => expo, maths, matrix
# ('tree',) => tree
# ('bruteforce',) => bruteforce
# ('dp',) => dp
# ('greedy',) => greedy
# ('geometry',) => geometry
# ('gcd',) => gcd
# ('backtracking',) => backtracking
# ('binarysearch', 'fibonacci', 'hashing') => binarysearch, fibonacci, hashing
# ('dp',) => dp
# ('greedy',) => greedy
# ('greedy',) => greedy
# ('dp',) =>
# ('expo', 'matrix', 'recurrence') => expo, matrix, recurrence
# ('gcd',) => gcd
# ('kruskal',) => kruskal
# ('tree',) =>
# ('tree',) => tree
# ('prime', 'segment', 'tree') => segment, tree
# ('greedy', 'heap', 'multiset') => greedy, heap, multiset
# ('fft', 'hard', 'maths') => fft, hard, maths
# ('basic',) => basic
# ('hard',) => hard
# ('gcd',) => gcd
# ('backtracking',) => backtracking
# ('maths',) => maths
# ('greedy',) => greedy
# ('greedy',) => greedy
# ('simulation',) => simulation
# ('map', 'sorting') => map, sorting
# ('dynamic',) =>
# ('geometry',) => geometry
# ('backtracking', 'enumeration') => backtracking, enumeration
# ('algebra',) => algebra
# ('constructive', 'greedy', 'implementation') =>
# ('strings',) => strings
# ('hard',) => hard, tree
# ('binarysearch', 'fibonacci', 'hashing') => binarysearch, fibonacci, hashing
# ('bfs', 'dijkstra') =>
# ('greedy', 'heap', 'multiset') => greedy, heap, multiset
# ('combinatorics',) => combinatorics
# ('expo', 'matrix', 'recurrence') => expo, matrix
# ('strings',) => strings
# ('strings',) => strings
# ('prime', 'segment', 'tree') => prime, segment, tree
# ('dp',) => dp
# ('dp',) => dp
# ('bfs', 'dijkstra') => bfs, dijkstra
# ('greedy',) => greedy
# ('maths',) => maths
# ('basic',) => basic
# ('gcd',) => gcd
# ('sorting',) => sorting
# ('basic',) => basic
# ('dp',) => dp
# ('greedy',) => greedy
# ('tree',) => tree
# ('binarysearch', 'fibonacci', 'hashing') => binarysearch, fibonacci, hashing
# ('gcd',) => gcd
# ('binarysearch', 'fibonacci', 'hashing') => binarysearch, fibonacci, hashing
# ('greedy',) => greedy
# ('strings',) => strings
# ('dynamic',) => dynamic
# ('basic',) => basic
# ('combinatorics',) => combinatorics
# ('geometry',) => geometry
# ('algorithm', 'hard') =>
# ('simulation',) => simulation
# ('greedy',) => greedy
# ('basic',) => basic
# ('gcd',) => gcd
# ('simulation',) => simulation
# ('greedy', 'heap', 'multiset') => greedy
# ('strings',) => strings
# ('number', 'theory') => number, theory
# ('geometry',) => geometry
# ('dp',) => dp
# ('deque',) => deque
# ('simulation',) => simulation
# ('gcd',) => gcd
# ('dynamic',) => dynamic
# ('binarysearch', 'fibonacci', 'hashing') => binarysearch, fibonacci, hashing
# ('binarysearch', 'dp', 'hard') => dp, hard
# ('simulation',) => simulation
# ('gcd',) => gcd
# ('greedy', 'heap', 'multiset') => greedy, heap, multiset
# ('combinatorics',) => combinatorics
# ('geometry',) => geometry
# ('dp',) => dp
# ('digraph', 'graph') => digraph, graph
# ('map', 'sorting') => map, sorting
# ('binarysearch', 'fibonacci', 'hashing') => binarysearch, fibonacci, hashing
# ('digraph', 'graph') => digraph, graph
# ('dynamic',) => combinatorics
# ('dp',) => dp
# ('algebra',) => algebra
# ('sorting',) =>
# ('dp',) => dp
# ('binarysearch', 'fibonacci', 'hashing') => binarysearch, fibonacci, hashing
# ('simulation', 'sorting') => simulation, sorting
# ('gcd',) => gcd
# ('combinatorics', 'greedy') => combinatorics, greedy
# ('greedy',) =>
# ('algorithm', 'greedy') =>
# ('strings',) => strings
# ('hard',) => hard
# ('dynamic',) =>
# ('algebra',) => algebra
# ('gcd',) => gcd
# ('gcd',) => gcd
# ('fenwick', 'inversions') => fenwick, inversions
# ('dp', 'dynamic') => dp, dynamic
# ('bfs', 'graph') =>
# ('map', 'sorting') => map, sorting
# ('greedy',) => greedy
# ('geometry',) => geometry
# ('game', 'theory') => game, theory
# ('simulation',) => simulation
# ('basic',) => basic
# ('hard', 'prime') => hard
# ('tree',) =>
# ('hard',) => hard
# ('gcd',) =>
# ('algebra',) => algebra
# ('simulation',) => simulation
# ('prime', 'segment', 'tree') => segment, tree
# ('simulation',) => simulation
# ('dp',) => dp
# ('number', 'theory') => number, theory
# ('tree',) => tree
# ('basic',) => basic
# ('gcd',) => gcd
# ('basic', 'pattern', 'stack') =>
# ('hard',) => hard
# ('basic',) => basic
# ('simulation',) => simulation
# ('algebra', 'series') => algebra, series
# ('dp',) => dp
# ('greedy',) => greedy
# ('expo', 'matrix', 'recurrence') => expo, matrix
# ('stack',) => stack
# ('bfs', 'dijkstra') => bfs, dijkstra
# ('greedy',) => greedy
# ('dp',) => dp
# ('simulation',) => simulation
# ('basic',) => basic
# ('gcd',) => gcd
# ('basic',) => basic
# ('maths',) => maths
# ('bruteforce',) => bruteforce
# ('hard', 'segment', 'tree') => hard
# ('gcd',) => gcd
# ('combinatorics',) => combinatorics
# ('map', 'sorting') => map, sorting
# ('maths',) =>
# ('probability', 'sorting') =>
# ('strings',) => strings
# ('stack',) => stack
# ('basic',) =>
# ('dynamic',) => dynamic
# ('geometry', 'maths') => maths
# ('maths',) => maths
# ('dynamic',) =>
# ('strings',) => strings
# ('number', 'theory') =>
# ('number', 'theory') =>
# ('greedy',) => greedy
# ('greedy',) => greedy
# ('dynamic',) => dynamic
# ('expo', 'maths', 'matrix') => expo, maths, matrix
# ('dynamic',) =>
# ('algebra',) => algebra
# ('strings',) => strings
# ('simulation',) => simulation
# ('strings',) => strings
# ('algebra',) => algebra
# ('bfs', 'graph') =>
# ('dp',) => dp
# ('dp',) => dp
# ('tree',) => tree
# ('kruskal',) => kruskal
# ('simulation',) => simulation
# ('tree',) => tree
# ('basic',) => basic
# ('binarysearch', 'fibonacci', 'hashing') => binarysearch, fibonacci, hashing
# ('greedy',) => greedy
# ('tree',) => tree
# ('simulation', 'sorting') => simulation, sorting
# ('greedy',) => greedy
# ('geometry',) => geometry
# ('dp',) => dp
# ('expo', 'matrix', 'recurrence') => expo, matrix, recurrence
# ('simulation',) => simulation
# ('dp',) => dp
# ('prime', 'segment', 'tree') => segment, tree
# ('dfs', 'sieve') =>
# ('maths',) => maths
# ('simulation',) => simulation
# ('hard',) => hard
# ('implementation',) => implementation
# ('algebra',) => algebra
# ('greedy',) => greedy
# ('combinatorics',) => combinatorics
# ('basic',) => basic
# ('dp',) => dp
# ('greedy',) => greedy
# ('basic', 'pattern', 'stack') => basic, pattern, stack
# ('bitwise', 'segment', 'tree') => bitwise, segment, tree
# ('tree',) => tree
# ('greedy',) => greedy
# ('simulation',) => simulation
# ('gcd',) => gcd
# ('greedy',) => greedy
# ('dp',) => dp
# ('backtracking',) => backtracking
# ('basic',) => basic
# ('binarysearch', 'fibonacci', 'hashing') => binarysearch, fibonacci, hashing
# ('sorting',) =>
# ('dp',) => dp
# ('geometry',) => hard
# ('simulation',) => simulation
# ('backtracking',) => backtracking
# ('greedy',) =>
# ('tree',) => tree
# ('adhoc',) => adhoc
# ('basic', 'graph') =>
# ('dp',) => dp
# ('simulation',) => simulation
# ('tree',) =>
# ('combinatorics', 'counting', 'game', 'theory') => combinatorics, counting, game, theory
# ('basic',) => basic
# ('greedy',) => greedy
# ('simulation',) => simulation
# ('greedy',) =>
# ('algebra',) => algebra
# ('advanced', 'maths') => hard
# ('simulation',) => simulation
# ('dynamic',) => dynamic
# ('deque',) => deque
# ('sorting',) => sorting
# ('number', 'theory') => number, theory
# ('kruskal',) => kruskal
# ('expo', 'maths', 'matrix') => expo, matrix
# ('simulation',) => simulation
# ('bfs', 'dijkstra') =>
# ('disjoint', 'hard', 'segment', 'set', 'stack', 'suffix', 'tree', 'trees') => disjoint, hard, segment, set, stack, suffix, tree, trees
# ('greedy',) => greedy
# ('dp',) => dp
# ('strings',) => strings
# ('fft', 'hard', 'maths') => fft, hard, maths
# ('geometry',) => geometry
# ('simulation',) => simulation
# ('algebra',) => algebra
# ('expo', 'matrix', 'recurrence') => expo, matrix, recurrence
# ('combinatorics',) => combinatorics
# ('dp',) => dp
# ('greedy',) => greedy
# ('game', 'theory') => game, theory
# ('game',) => game
# ('simulation',) => simulation
# ('tree',) => tree
# ('game', 'theory') =>
# ('geometry',) => geometry
# ('digraph', 'graph') => digraph, graph
# ('maths',) =>
# ('prime', 'segment', 'tree') => segment, tree
# ('adhoc',) => adhoc
# ('bfs', 'dijkstra') => bfs, dijkstra
# ('strings',) => strings
# ('greedy',) => greedy
# ('adhoc',) => adhoc
# ('basic',) => basic
# ('greedy',) => greedy
# ('gcd',) => gcd
# ('combinatorics',) => combinatorics
# ('dp',) => dp
# ('segment', 'tree') => segment, tree
# ('dp',) => dp
# ('implementation',) => implementation
# ('fft', 'hard', 'maths') => hard
# ('game', 'theory') => game, theory
# ('tree',) =>
# ('dp',) => dp
# ('combinatorics',) => combinatorics
# ('greedy',) => greedy
# ('strings',) => strings
# ('gcd',) => gcd
# ('bfs', 'graph') => bfs, graph
# ('maths',) => maths
# ('gcd',) => gcd
# ('tree',) => tree
# ('tree',) => tree
# ('greedy',) => algebra
# ('greedy', 'heap', 'multiset') => greedy, heap, multiset
# ('greedy',) => greedy
# ('algorithm', 'greedy') =>
# ('greedy',) => greedy
# ('dp',) => dp
# ('dynamic',) => dynamic
# ('bfs', 'graph') => bfs
# ('bfs', 'dijkstra') => bfs, dijkstra
# ('gcd',) => gcd
# ('greedy',) => greedy
# ('gcd',) => gcd
# ('adhoc',) => adhoc
# ('basic',) => basic
# ('tree',) =>
# ('tree',) => tree
# ('maths',) => maths
# ('strings',) => strings
# ('hard',) => hard
# ('gcd',) => gcd
# ('gcd',) => gcd
# ('geometry',) => geometry
# ('expo', 'matrix', 'recurrence') => expo, matrix, recurrence
# ('dynamic',) => dynamic
# ('simulation',) => simulation
# ('expo', 'maths', 'matrix') => expo, matrix
# ('binarysearch', 'fibonacci', 'hashing') => binarysearch, fibonacci, hashing
# ('combinatorics',) =>
# ('tree',) => tree
# ('gcd',) =>
# ('tree',) =>
# ('gcd',) => gcd
# ('segment', 'tree') => segment, tree
# ('greedy',) => greedy
# ('dp',) => dp
# ('greedy',) => greedy
# ('simulation',) => simulation
# ('simulation',) => simulation
# ('gcd',) => gcd
# ('expo', 'matrix', 'recurrence') => expo, matrix, recurrence
# ('map', 'sorting') => map, sorting
# ('geometry',) =>
# ('graph',) => graph
# ('greedy',) => greedy
# ('dp',) =>
# ('dynamic',) => dynamic
# ('adhoc',) => adhoc
# ('tree',) =>
# ('simulation',) => simulation
# ('dynamic',) => dynamic
# ('game', 'theory') => game, theory
# ('sorting',) => sorting
# ('dp',) =>
# ('gcd',) => gcd
# ('tree',) => tree
# ('bfs', 'dijkstra') => bfs, dijkstra
# ('greedy',) => greedy
# ('maths',) => maths
# ('tree',) =>
# ('binarysearch', 'fibonacci', 'hashing') => binarysearch, fibonacci, hashing
# ('gcd',) => gcd
# ('gcd',) => gcd
# ('basic', 'pattern', 'stack') => basic, pattern, stack
# ('adhoc',) => adhoc
# ('bfs', 'dijkstra') => bfs, dijkstra
# ('sorting',) => sorting
# ('greedy',) =>
# ('digraph', 'graph') =>
# ('basic',) => basic
# ('expo', 'matrix') =>
# ('tree',) => tree
# ('dp',) => dp
# ('dp',) => dp
# ('strings',) => strings
# ('greedy',) => greedy
# ('gcd',) =>
# ('greedy',) =>
# ('simulation',) => simulation
# ('gcd',) => gcd
# ('binarysearch', 'fibonacci', 'hashing') => binarysearch, fibonacci, hashing
# ('tree',) => tree
# ('sorting',) => greedy
# ('gcd',) => gcd
# ('combinatorics',) => combinatorics
# ('bitwise', 'segment', 'tree') => bitwise, segment, tree
# ('simulation',) => simulation
# ('binarysearch', 'fibonacci', 'hashing') => binarysearch, fibonacci, hashing
# ('dp',) =>
# ('greedy',) =>
# ('dynamic',) => dynamic
# ('dp',) => dp
# ('algebra', 'series') =>
# ('gcd',) => gcd
# ('maths',) =>
# ('dp',) =>
# ('graph', 'matching') => graph, matching
# ('advanced', 'maths') => advanced, maths
# ('basic', 'pattern', 'stack') => basic, pattern, stack
# ('strings',) => strings
# ('gcd',) => gcd
# ('dp',) => dp
# ('maths',) => maths
# ('gcd',) => gcd
# ('implementation',) =>
# ('greedy',) => greedy
# ('combinatorics',) => combinatorics
# ('game', 'theory') => game, theory
# ('combinatorics',) => combinatorics
# ('adhoc',) => adhoc
# ('greedy',) => greedy
# ('dp',) => dp
# ('sorting',) => sorting
# ('tree',) => tree
# ('tree',) =>
# ('dp',) => dp
# ('greedy',) => greedy
# ('tree',) => tree
# ('dp',) => dp
# ('dp',) => dp
# ('dp',) => dp
# ('combinatorics',) => combinatorics
# ('simulation',) => simulation
# ('backtracking',) =>
# ('gcd',) => gcd
# ('greedy',) => greedy
# ('combinatorics', 'counting', 'game', 'theory') =>
# ('simulation',) => simulation
# ('dp',) => dp
# ('simulation', 'sorting') => simulation, sorting
# ('gcd',) => gcd
# ('strings',) => strings
# ('dp',) => dp
# ('maths',) => maths
# ('gcd',) => gcd
# ('gcd',) => gcd
# ('dp',) => dp
# ('tree',) => tree
# ('gcd',) => gcd
# ('algebra', 'series') =>
# ('strings',) => strings
# ('gcd',) => gcd
# ('tree',) => tree
# ('dp',) => dp
# ('expo', 'maths', 'matrix') => expo, maths, matrix
# ('dp',) => dp
# ('backtracking',) => backtracking
# ('geometry',) => geometry
# ('dp',) => dp
# ('dynamic',) => dynamic
# ('simulation',) => simulation
# ('tree',) => tree
# ('dynamic',) =>
# ('strings',) => strings
# ('dp',) => dp
# ('algebra',) =>
# ('hard',) => hard
# ('greedy',) => greedy
# ('dynamic',) => dynamic
# ('gcd',) =>
# ('simulation',) => simulation
# ('gcd',) => gcd
# ('bitwise', 'segment', 'tree') => bitwise, segment, tree
# ('gcd',) =>
# ('bfs', 'graph') => bfs, graph
# ('dp', 'dynamic') => dynamic
# ('basic', 'graph') => basic
# ('binary', 'search') =>
# ('geometry',) => geometry
# ('greedy', 'heap', 'multiset') => greedy, heap, multiset
# ('algebra',) => algebra
# ('combinatorics', 'hard') => combinatorics, hard
# ('kruskal',) => kruskal
# ('binarysearch', 'fibonacci', 'hashing') => binarysearch, fibonacci, hashing
# ('bitwise', 'segment', 'tree') => bitwise, segment, tree
# ('digraph', 'graph') =>
# ('dynamic',) => dynamic
# ('gcd',) => gcd
# ('digraph', 'graph') => graph
# ('combinatorics',) => combinatorics
# ('prime', 'segment', 'tree') => segment
# ('strings',) => strings
# ('basic',) => basic
# ('greedy',) => greedy
# ('gcd',) => gcd
# ('maths',) => maths
# ('simulation',) => simulation
# ('dp',) => dp
# ('basic', 'pattern', 'stack') => basic, pattern, stack
# ('basic',) => basic
# ('dp',) => dp
# ('dp',) => dp
# ('tree',) => tree
# ('simulation',) => simulation
# ('tree',) =>
# ('maths',) => maths
# ('strings',) => strings
# ('tree',) => tree
# ('map', 'sorting') => map, sorting
# ('gcd',) => gcd
# ('simulation',) => simulation
# ('dp',) => dp
# ('gcd',) => gcd
# ('bitwise',) => bitwise
# ('maths',) => maths
# ('binarysearch', 'fibonacci', 'hashing') => binarysearch, fibonacci, hashing
# ('bfs', 'dijkstra') => bfs, dijkstra
# ('dp',) => dp
# ('bitwise',) => bitwise
# ('dp',) => dp
# ('basic', 'pattern', 'stack') => basic, pattern, stack
# ('algorithm', 'hard') => algorithm, hard
# ('expo', 'maths', 'matrix') => expo, maths, matrix
# ('strings',) => strings
# ('strings',) => strings
# ('gcd',) => greedy
# ('tree',) => tree
# ('gcd',) => gcd
# ('tree',) => tree
# ('gcd',) => gcd
# ('expo', 'matrix', 'recurrence') =>
# ('bipartite', 'geometry', 'hard', 'maxflow', 'set') => bipartite, geometry, hard, maxflow, set
# ('combinatorial', 'game', 'theory') => game, theory
# ('greedy',) => greedy
# ('simulation', 'sorting') => simulation, sorting
# ('geometry',) => geometry
# ('graph', 'hard') => graph, hard
# ('simulation', 'sorting') => simulation, sorting
# ('bitwise',) =>
# ('hard',) => hard
# ('gcd',) => gcd
# ('tree',) =>
# ('dp',) => dp
# ('simulation',) => simulation
# ('bitwise',) =>
# ('tree',) =>
# ('tree',) => tree
# ('strings',) => strings
# ('number', 'theory') => number, theory
# ('digraph', 'graph') => digraph, graph
# ('gcd',) => gcd
# ('dp',) => dp
# ('simulation',) => simulation
# ('binarysearch', 'fibonacci', 'hashing') => binarysearch, fibonacci, hashing
# ('hard',) => hard
# ('game', 'theory') => game, theory
# ('bfs', 'dijkstra') => bfs, dijkstra
# ('simulation',) => simulation
# ('greedy',) => greedy
# ('stack',) => stack
# ('basic',) => basic
# ('gcd',) => gcd
# ('expo', 'matrix', 'recurrence') => expo, matrix, recurrence
# ('combinatorics',) => combinatorics
# ('digraph', 'graph') => digraph, graph
# ('dp',) => dp
# ('binarysearch', 'fibonacci', 'hashing') => binarysearch, fibonacci, hashing
# ('bfs', 'dijkstra') => bfs, dijkstra
# ('dynamic',) => dynamic
# ('game', 'theory') => game, theory
# ('basic',) => basic
# ('segment', 'tree') => segment, tree
# ('strings',) => strings
# ('dynamic',) => dynamic
# ('simulation',) => simulation
# ('basic',) => basic
# ('tree',) => tree
# ('digraph', 'graph') => digraph, graph
# ('tree',) => tree
# ('basic',) => basic
# ('game', 'theory') => game
# ('expo', 'matrix', 'recurrence') => expo, matrix
# ('expo', 'maths', 'matrix') => expo, maths, matrix
# ('dp',) => dp
# ('dp',) => dp
# ('sorting',) => sorting
# ('dp',) => dp
# ('simulation',) => simulation
# ('simulation',) => simulation
# ('binarysearch', 'fibonacci', 'hashing') => binarysearch, fibonacci, hashing
# ('combinatorics',) => combinatorics
# ('greedy',) => greedy
# ('stack',) => stack
# ('maths',) => maths
# ('dp',) => greedy
# ('greedy', 'heap', 'multiset') => greedy
# ('greedy',) => greedy
# ('hard', 'segment', 'tree') => hard, segment, tree
# ('greedy', 'heap', 'multiset') => greedy, heap, multiset
# ('adhoc',) => adhoc
# ('geometry',) =>
# ...
# ('dynamic',) => dynamic
# ('combinatorics',) => combinatorics
# ('algebra',) => algebra
# ('gcd',) =>
# ('basic',) => basic
# ('greedy', 'heap', 'multiset') => greedy, heap, multiset
# ('expo', 'matrix', 'recurrence') => expo, matrix, recurrence
# ('number', 'theory') => number, theory
# ('maths',) => maths
# ('gcd',) => gcd
# ('gcd',) =>
# ('greedy',) => greedy
# ('hard',) => hard
# ('tree',) => tree
# ('combinatorics',) => combinatorics
# ('dynamic',) => dynamic
# ('greedy',) => greedy
# ('greedy',) => greedy
# ('gcd',) =>
# ('digraph', 'graph') => digraph, graph
# ('dynamic',) =>
# ('simulation',) => simulation
# ('gcd',) =>
# ('greedy',) =>
# ('simulation',) => simulation
# ('tree',) => tree
# ('gcd',) => gcd
# ('combinatorics',) => combinatorics
# ('dp',) =>
# ('strings',) => strings
# ('strings',) => strings
# ('maths',) => maths
# ('binarysearch', 'fibonacci', 'hashing') => binarysearch, fibonacci, hashing
# ('basic', 'pattern', 'stack') => basic, pattern, stack
# ('gcd',) => gcd
# ('tree',) =>
# ('strings',) => strings
# ('adhoc',) => adhoc
# ('hard', 'suffix') => hard, suffix
# ('tree',) => tree
# ('dynamic',) => dynamic
# ('adhoc',) => adhoc
# ('dp',) => dp
# ('basic', 'pattern', 'stack') => basic, stack
# ('greedy', 'heap', 'multiset') => greedy, heap, multiset
# ('sorting',) => sorting
# ('binarysearch', 'fibonacci', 'hashing') => binarysearch, fibonacci, hashing
# ('combinatorics', 'greedy') => combinatorics, greedy
# ('expo', 'maths', 'matrix') => expo, maths, matrix
# ('hard',) => combinatorics, hard
# ('bfs', 'dijkstra') => bfs, dijkstra
# ('greedy',) => greedy
# ('greedy',) => greedy
# ('kruskal',) => kruskal
# ('simulation',) => simulation
# ('bfs', 'dijkstra') => bfs, dijkstra
# ('expo', 'maths', 'matrix') => expo, maths, matrix
# ('gcd',) =>
# ('gcd',) => gcd
# ('greedy',) => greedy
# ('gcd',) => gcd
# ('combinatorics',) => combinatorics
# ('bfs', 'dijkstra') => bfs, dijkstra
# ('simulation',) => simulation
# ('dp',) => dp
# ('simulation',) => simulation
# ('binarysearch', 'fibonacci', 'hashing') => binarysearch, fibonacci, hashing
# ('gcd',) => gcd
# ('hard', 'permutation', 'probability') => hard, permutation, probability
# ('simulation',) => simulation
# ('dp',) => dp
# ('dp',) => dp
# ('gcd',) => gcd
# ('dp',) => dp
# ('prime', 'segment', 'tree') => tree
# ('maths',) => maths
# ('prime', 'segment', 'tree') =>
# ('bfs', 'graph') =>
# ('tree',) => tree
# ('bfs', 'graph') => bfs, graph
# ('number', 'theory') => number, theory
# ('dp',) => dp
# ('bruteforce',) => bruteforce
# ('simulation',) => simulation
# ('gcd',) => gcd
# ('bfs', 'dijkstra') => bfs, dijkstra
# ('kruskal',) => kruskal
# ('simulation',) => simulation
# ('tree',) => tree
# ('tree',) => tree
# ('dynamic',) => combinatorics, dynamic
# ('number', 'theory') =>
# ('map', 'sorting') => map, sorting
# ('gcd',) => gcd
# ('strings',) => strings
# ('greedy',) =>
# ('implementation',) =>
# ('maths',) => maths
# ('digraph', 'graph') => digraph, graph
# ('simulation',) => simulation
# ('stack',) => stack
# ('greedy',) => greedy
# ('gcd',) => gcd
# ('tree',) => tree
# ('combinatorics', 'counting', 'game', 'theory') =>
# ('greedy',) =>
# ('tree',) => tree
# ('greedy',) =>
# ('strings',) => strings
# ('adhoc',) => adhoc
# ('simulation',) => simulation
# ('number', 'theory') =>
# ('greedy',) => greedy
# ('gcd',) => gcd
# ('dynamic',) => dp, dynamic
# ('hard',) => hard
# ('disjoint', 'hard', 'segment', 'set', 'stack', 'suffix', 'tree', 'trees') => disjoint, hard, segment, set, stack, suffix, tree, trees
# ('combinatorics',) =>
# ('gcd',) => gcd
# ('simulation', 'sorting') =>
# ('strings',) => strings
# ('dynamic',) => dynamic
# ('tree',) => tree
# ('simulation',) => simulation
# ('hard',) => hard
# ('gcd',) => gcd
# ('number', 'theory') =>
# ('hard',) => hard
# ('greedy',) => greedy
# ('simulation',) => simulation
# ('simulation',) => simulation
# ('strings',) => strings
# ('bfs', 'dijkstra') => bfs, dijkstra
# ('dp',) =>
# ('number', 'theory') =>
# ('strings',) => strings
# ('game', 'theory') => game, theory
# ('hard',) => hard
# ('hard',) => hard
# ('sorting',) => sorting
# ('gcd',) => gcd
# ('map', 'sorting') => map, sorting
# ('basic',) => basic
# ('dp',) => dp
# ('gcd',) => gcd
# ('number', 'theory') => number, theory
# ('greedy',) => greedy
# ('basic', 'pattern', 'stack') =>
# ('strings',) => strings
# ('hard',) => hard
# ('gcd',) => gcd
# ('dp',) => dp
# ('combinatorics', 'greedy') =>
# ('greedy',) => greedy
# ('binarysearch', 'fibonacci', 'hashing') => binarysearch, fibonacci, hashing
# ('combinatorics', 'divide', 'fft', 'hard') => combinatorics, divide, fft, hard
# ('greedy',) =>
# ('expo', 'matrix', 'recurrence') => expo, matrix, recurrence
# ('maths',) => maths
# ('algebra',) => algebra
# ('greedy',) => greedy
# ('gcd',) => gcd
# ('strings',) => strings
# ('greedy',) => greedy
# ('fft', 'hard', 'maths') => fft, hard, maths
# ('dp',) => dp
# ('hard', 'segment', 'tree') => hard, segment, tree
# ('expo', 'matrix', 'recurrence') => expo, matrix
# ('dp',) => dp
# ('simulation',) => simulation
# ('simulation',) => simulation
# ('gcd',) => gcd
# ('gcd',) => gcd
# ('adhoc',) => adhoc
# ('greedy',) => greedy
# ('tree',) => tree
# ('graph', 'matching') =>
# ('greedy',) =>
# ('greedy',) => greedy
# ('binarysearch', 'fibonacci', 'hashing') => binarysearch, fibonacci, hashing
# ('simulation',) => simulation
# ('binarysearch', 'fibonacci', 'hashing') => binarysearch, fibonacci, hashing
# ('expo', 'matrix', 'recurrence') => expo, matrix, recurrence
# ('simulation',) => simulation
# ('hard',) => hard
# ('simulation',) => simulation
# ('algebra',) => algebra
# ('maths',) => maths
# ('greedy',) => greedy
# ('implementation',) =>
# ('dp',) => dp
# ('tree',) => tree
# ('tree',) => tree
# ('combinatorics',) => combinatorics
# ('basic',) => basic
# ('hard', 'number', 'theory') => hard, number, theory
# ('algebra', 'series') =>
# ('gcd',) => gcd
# ('fft', 'hard', 'maths') => fft, hard, maths
# ('strings',) => strings
# ('geometry', 'maths') => geometry, maths
# ('combinatorics',) => combinatorics
# ('greedy',) => greedy
# ('combinatorics',) => combinatorics
# ('simulation',) => simulation
# ('bfs', 'dijkstra') => bfs, dijkstra
# ('greedy',) => greedy
# ('segment', 'tree') => segment, tree
# ('strings',) => strings
# ('dynamic',) => dynamic
# ('gcd',) => gcd
# ('simulation',) => simulation
# ('basic',) => basic
# ('greedy',) => greedy
# ('simulation',) => simulation
# ('deque',) => deque
# ('implementation',) => implementation
# ('simulation',) => simulation
# ('sorting',) =>
# ('expo', 'matrix', 'recurrence') => expo, matrix, recurrence
# ('combinatorics',) => combinatorics
# ('tree',) => tree
# ('gcd',) => gcd
# ('dfs', 'sieve') =>
# ('strings',) => strings
# ('gcd',) =>
# ('constructive', 'greedy', 'implementation') => greedy
# ('dp',) => dp
# ('greedy',) => greedy
# ('geometry',) => geometry
# ('constructive', 'greedy', 'implementation') => constructive, greedy, implementation
# ('simulation',) => simulation
# ('greedy',) => greedy
# ('map', 'sorting') => map, sorting
# ('expo', 'maths', 'matrix') => expo, maths, matrix
# ('greedy',) => greedy
# ('bruteforce',) =>
# ('algorithm', 'hard') => algorithm, hard
# ('greedy',) => greedy
# ('gcd',) => gcd
# ('basic',) => basic
# ('greedy',) => greedy
# ('simulation',) => simulation
# ('dp',) => dp
# ('sorting',) => sorting
# ('sorting',) => sorting
# ('simulation',) => simulation
# ('dp',) => dp
# ('combinatorics', 'counting', 'game', 'theory') =>
# ('combinatorics',) => combinatorics
# ('simulation',) => simulation
# ('simulation', 'sorting') =>
# ('tree',) =>
# ('strings',) => strings
# ('hashing',) =>
# ('maths',) =>
# ('greedy',) => greedy
# ('bfs', 'dijkstra') =>
# ('gcd',) => gcd
# ('expo', 'matrix', 'recurrence') =>
# ('expo', 'matrix', 'recurrence') => expo, matrix, recurrence
# ('dynamic',) => dynamic
# ('expo', 'matrix', 'recurrence') => expo, matrix, recurrence
# ('geometry', 'maths') => geometry, maths
# ('simulation',) => simulation
# ('strings',) => strings
# ('maths',) => maths
# ('gcd',) =>
# ('sorting',) => sorting
# ('gcd',) => gcd
# ('greedy',) =>
# ('dp',) => dp
# ('bfs', 'dijkstra') => bfs, dijkstra
# ('fft', 'hard', 'maths') => fft, hard, maths
# ('hard',) => hard
# ('kruskal',) => kruskal
# ('tree',) => tree
# ('sorting',) => sorting
# ('gcd',) => gcd
# ('basic',) => basic
# ('tree',) => tree
# ('simulation',) => simulation
# ('simulation',) => simulation
# ('combinatorics',) => combinatorics
# ('dp', 'hard') => dp, hard
# ('simulation',) => simulation
# ('tree',) => tree
# ('algebra',) => algebra
# ('greedy', 'heap', 'multiset') => greedy, heap, multiset
# ('algebra',) => algebra
# ('greedy',) => greedy
# ('tree',) => tree
# ('implementation',) =>
# ('adhoc',) => adhoc
# ('greedy',) => greedy
# ('graph',) =>
# ('maths',) => maths
# ('implementation',) => implementation
# ('greedy', 'heap', 'multiset') => greedy, heap, multiset
# ('maths',) => maths
# ('simulation',) => simulation
# ('simulation',) => simulation
# ('bfs', 'dijkstra') => bfs, dijkstra
# ('expo', 'matrix', 'recurrence') => expo, matrix, recurrence
# ('segment', 'tree') => segment, tree
# ('stack',) => stack
# ('dynamic',) => dynamic
# ('simulation',) => simulation
# ('graph',) => graph
# ('prime', 'segment', 'tree') => tree
# ('basic',) => basic
# ('simulation',) => simulation
# ('greedy', 'hard') => greedy, hard
# ('dp',) => dp
# ('simulation', 'sorting') =>
# ('strings',) => strings
# ('sorting',) => sorting
# ('hard', 'segment', 'tree') => hard, segment, tree
# ('bfs', 'binary', 'dfs', 'search', 'sorting') => bfs, binary, dfs, search, sorting
# ('tree',) => tree
# ('simulation',) => simulation
# ('tree',) => tree
# ('map', 'sorting') => map, sorting
# ('hard', 'number', 'theory') => hard, number, theory
# ('greedy', 'heap', 'multiset') => greedy, heap, multiset
# ('greedy',) => greedy
# ('greedy',) => greedy
# ('combinatorics',) => combinatorics
# ('gcd',) => gcd
# ('tree',) => tree
# ('number', 'theory') => number, theory
# ('geometry',) =>
# ('basic',) => basic
# ('gcd',) => gcd
# ('greedy',) => greedy
# ('gcd',) => gcd
# ('adhoc',) =>
# ('gcd',) => gcd
# ('geometry',) => geometry
# ('gcd',) => gcd
# ('strings',) => strings
# ('maths',) => maths
# ('dp',) => dp
# ('dp',) =>
# ('bipartite', 'geometry', 'hard', 'maxflow', 'set') => bipartite, geometry, hard, maxflow, set
# ('backtracking',) => backtracking
# ('sorting',) =>
# ('dfs', 'sieve') => dfs, sieve
# ('maths',) => maths
# ('combinatorics',) => combinatorics
# ('dp',) => greedy
# ('dp',) =>
# ('expo', 'matrix', 'recurrence') => expo, matrix
# ('gcd',) => gcd
# ('geometry',) => geometry
# ('combinatorics',) => combinatorics
# ('tree',) => tree
# ('basic', 'graph') =>
# ('expo', 'matrix', 'recurrence') => expo, matrix, recurrence
# ('greedy', 'heap', 'multiset') => greedy, heap, multiset
# ('disjoint', 'hard', 'segment', 'set', 'stack', 'suffix', 'tree', 'trees') => disjoint, hard, segment, set, stack, suffix, tree, trees
# ('greedy',) => greedy
# ('simulation',) => simulation
# ('greedy',) =>
# ('gcd',) => gcd
# ('hard',) => hard
# ('adhoc',) => adhoc
# ('bfs', 'dijkstra') => bfs, dijkstra
# ('simulation',) => simulation
# ('simulation',) => simulation
# ('maths',) => maths
# ('tree',) =>
# ('maths',) => maths
# ('combinatorics',) => combinatorics
# ('hard',) => hard
# ('dp',) => dp
# ('simulation',) => simulation
# ('graph',) => graph
# ('simulation',) => simulation
# ('bfs', 'graph') =>
# ('gcd',) => gcd
# ('basic',) => basic
# ('backtracking',) => backtracking
# ('maths',) =>
# ('greedy', 'heap', 'multiset') => greedy, heap, multiset
# ('greedy',) => greedy
# ('number', 'theory') =>
# ('bfs', 'dijkstra') => bfs, dijkstra
# ('dynamic',) => dynamic
# ('dp',) => dp
# ('fenwick', 'inversions') => segment, tree
# ('combinatorics',) =>
# ('combinatorics',) =>
# ('greedy',) => greedy
# ('expo', 'matrix', 'recurrence') => expo, matrix, recurrence
# ('tree',) =>
# ('maths',) => maths
# ('greedy',) => greedy
# ('bfs', 'graph') => bfs, graph
# ('gcd',) => gcd
# ('dynamic',) => dynamic
# ('greedy', 'hard', 'pointers', 'segment', 'tree') => greedy, hard, pointers, segment, tree
# ('gcd',) => gcd
# ('greedy',) => greedy
# ('gcd',) => gcd
# ('combinatorics',) => combinatorics
# ('basic',) => basic
# ('gcd',) => gcd
# ('tree',) =>
# ('gcd',) => gcd
# ('maths',) => maths
# ('tree',) =>
# ('digraph', 'graph') =>
# ('number', 'theory') => number, theory
# ('tree',) => tree
# ('simulation',) => simulation
# ('kruskal',) => kruskal
# ('greedy',) =>
# ('bfs', 'dijkstra') => bfs, dijkstra
# ('bfs', 'dijkstra') => bfs, dijkstra
# ('gcd',) => gcd
# ('greedy',) =>
# ('geometry', 'maths') => geometry, maths
# ('geometry',) => geometry
# ('tree',) => tree
# ('greedy',) => greedy
# ('backtracking',) =>
# ('hard', 'segment', 'tree') => hard, segment, tree
# ('game',) => game
# ('map', 'sorting') => map, sorting
# ('strings',) => strings
# ('gcd',) => gcd
# ('gcd',) => gcd
# ('tree',) => tree
# ('simulation',) => simulation
# ('simulation',) => simulation
# ('hard',) => hard
# ('expo', 'matrix', 'recurrence') => expo, maths, matrix
# ('digraph', 'graph') => digraph, graph
# ('dp',) => dp
# ('dp',) => dp
# ('tree',) => tree
# ('deque',) => deque
# ('dp',) => dp
# ('gcd',) => gcd
# ('basic',) => basic
# ('maths',) =>
# ('dfs', 'sieve') => dfs, sieve
# ('maths',) => maths
# ('greedy', 'hard', 'pointers', 'segment', 'tree') => greedy, hard, pointers, segment, tree
# ('dynamic',) => dynamic
# ('binary', 'search') => binary, search
# ('dynamic',) => dynamic
# ('fft', 'hard', 'maths') => hard
# ('greedy',) =>
# ('sorting',) =>
# ('strings',) => strings
# ('simulation',) => simulation
# ('dynamic',) => dynamic
# ('simulation',) => simulation
# ('digraph', 'graph') =>
# ('kruskal',) => kruskal
# ('disjoint', 'set') =>
# ('segment', 'tree') => segment, tree
# ('simulation',) => simulation
# ('basic',) => basic
# ('combinatorics',) => combinatorics
# ('game', 'theory') => game, theory
# ('number', 'theory') =>
# ('hard', 'number', 'theory') => hard
# ('combinatorics',) => combinatorics
# ('bruteforce',) => bruteforce
# ('maths',) => maths
# ('backtracking',) =>
# ('simulation',) => simulation
# ('digraph', 'graph') =>
# ('sorting',) => sorting
# ('gcd',) => gcd
# ('greedy',) => greedy
# ('strings',) => strings
# ('implementation',) => implementation
# ('greedy', 'heap', 'multiset') => greedy, heap, multiset
# ('greedy',) => greedy
# ('tree',) => tree
# ('strings',) => strings
# ('backtracking',) => backtracking
# ('dynamic',) => dynamic
# ('basic',) => basic
# ('number', 'theory') => gcd, number, theory
# ('simulation', 'sorting') => simulation, sorting
# ('dp',) => dp
# ('dp',) => dp
# ('stack',) => stack
# ('dp',) => dp
# ('combinatorics',) => combinatorics
# ('dp',) => dp
# ('greedy',) => greedy
# ('combinatorics', 'counting', 'game', 'theory') => combinatorics
# ('basic',) => basic
# ('basic',) => basic
# ('greedy',) => greedy
# ('greedy',) =>
# ('tree',) => tree
# ('maths',) => maths
# ('kruskal',) =>
# ('simulation',) => simulation
# ('number', 'theory') => number, theory
# ('hard', 'suffix') => hard
# ('greedy',) => greedy
# ('expo', 'maths', 'matrix') => expo, maths, matrix
# ('expo', 'matrix', 'recurrence') =>
# ('simulation',) => simulation
# ('simulation',) => simulation
# ('simulation',) => simulation
# ('dynamic',) => dynamic
# ('binarysearch', 'fibonacci', 'hashing') => binarysearch, fibonacci, hashing
# ('fft', 'hard', 'maths') => fft, hard, maths
# ('dp',) =>
# ('greedy',) => greedy
# ('deque',) => deque
# ('combinatorics',) => combinatorics
# ('tree',) => tree
# ('fenwick', 'inversions') => fenwick, inversions
# ('strings',) => strings
# ('strings',) => strings
# ('simulation',) => simulation
# ('hard', 'prime') => hard, prime
# ('gcd',) =>
# ('simulation',) => simulation
# ('bfs', 'dijkstra') => bfs, dijkstra
# ('gcd',) => gcd
# ('greedy',) => greedy
# ('algebra',) => algebra
# ('map', 'sorting') => map, sorting
# ('adhoc',) =>
# ('backtracking',) => backtracking
# ('simulation',) => simulation
# ('strings',) => strings
# ('algebra',) => algebra
# ('algebra',) => algebra
# ('game', 'theory') => game, theory
# ('bruteforce',) => bruteforce
# ('dp',) =>
# ('dynamic',) => dynamic
# ('gcd',) => gcd
# ('stack',) => stack
# ('binarysearch', 'fibonacci', 'hashing') => binarysearch, fibonacci, hashing
# ('binarysearch', 'fibonacci', 'hashing') => binarysearch, fibonacci, hashing
# ('segment', 'tree') => segment, tree
# ('greedy',) => greedy
# ('gcd',) => gcd
# ('sorting',) =>
# ('kruskal',) => kruskal
# ('greedy',) => maths
# ('tree',) =>
# ('gcd',) => gcd
# ('simulation', 'sorting') => simulation, sorting
# ('strings',) => strings
# ('map', 'sorting') => map, sorting
# ('map', 'sorting') => map, sorting
# ('gcd',) => gcd
# ('gcd',) => gcd
# ('tree',) => tree
# ('combinatorics',) => combinatorics
# ('tree',) => tree
# ('probability', 'sorting') => probability, sorting
# ('gcd',) => gcd
# ('binarysearch', 'fibonacci', 'hashing') => binarysearch, fibonacci, hashing
# ('adhoc',) => adhoc
# ('maths',) => maths
