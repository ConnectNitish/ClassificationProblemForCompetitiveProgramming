# %%
import numpy as np
import pandas as pd
import ssl
import copy
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline
import re
import random
import pickle
from pprint import pprint


from sklearn.metrics import hamming_loss, roc_auc_score
from sklearn.metrics import confusion_matrix 
from sklearn.model_selection import train_test_split 

from nltk.stem import PorterStemmer
from nltk.corpus import wordnet
from nltk.stem import WordNetLemmatizer
from nltk import pos_tag
from nltk.corpus import stopwords 
from nltk.tokenize import word_tokenize 
import wordcloud

from sklearn.pipeline import Pipeline
from sklearn.metrics import accuracy_score, recall_score, precision_score, f1_score, roc_curve
from sklearn.linear_model import LogisticRegression, SGDClassifier
from sklearn.feature_extraction.text import CountVectorizer
from sklearn.svm import LinearSVC, NuSVC
from sklearn.naive_bayes import MultinomialNB
from sklearn.feature_extraction.text import TfidfTransformer, TfidfVectorizer
from sklearn.multiclass import OneVsRestClassifier
from sklearn.preprocessing import MultiLabelBinarizer



import scikitplot as skplt
import matplotlib.pyplot as plt

from keras import optimizers
from keras.losses import binary_crossentropy
from keras.metrics import binary_accuracy
from keras.layers import Dense, Embedding, LSTM, SpatialDropout1D
from keras.models import Sequential
from keras.preprocessing.text import Tokenizer
from keras.preprocessing.sequence import pad_sequences
from keras.utils.np_utils import to_categorical
from keras.callbacks import EarlyStopping

from scipy.special import softmax

ssl._create_default_https_context = ssl._create_unverified_context
# Out:
# Using TensorFlow backend.

# %%
def clean_statement(statement):
#     x = re.sub('-', ' ', x)
    statement = re.sub('$', ' ', statement)
    statement = re.sub('[^A-Za-z]+', ' ', statement)
    statement = re.sub('[,|.|?|\n]|\t', '', statement)
    statement = re.sub('n\'t', ' ', statement)
    statement = re.sub('submission|submissions|Submission|submission|th ', '', statement)
    statement = re.sub('one|two|given|need', '', statement)
    
    return statement

# %%
def process_problem_statement(q_statement):
    
    q_statement = clean_statement(q_statement)
    
#     q_statement = re.sub('[^A-Za-z]+', ' ', q_statement)
    
    tokens = word_tokenize(q_statement)
    
    stoplist = set(stopwords.words('english'))
    
    word_list = [i for i in q_statement.lower().split() if i not in stoplist]
    
    ps = PorterStemmer()
    
#     word_list = [ps.stem(word) for word in word_list]
    
    q_statement = ' '.join(word_list)
    
#     print(q_statement)
    
    return q_statement

# %%
def process_problem_solution(solution):
    
#     solution = clean_statement(solution)
    
    tokens = word_tokenize(solution)
    
    stoplist = set(stopwords.words('english'))
    
    word_list = [i for i in solution.lower().split() if i not in stoplist]
    
#     ps = PorterStemmer()
    
#     word_list = [ps.stem(word) for word in word_list]
    
    solution = ' '.join(word_list)
    
#     print(q_statement)
    
    return solution

# %%
def process_time_taken(time_col):
#     print(time_col.split())
    return time_col.split()[0]

# %%
def process_tags(all_tags_list,tag_col):
    
#     print(tag_col)
    tags_present = list(re.split(',',tag_col))
    return tags_present

# %%
def get_all_distinct_tags(tags_col):
    
    tags_list = []
    
    t_sets = set(tags_list)
    
    for row in tags_col:
#         print(row)
        t_list = re.split(',',row)
#         print(t_list)
        t_sets = t_sets.union(set(t_list))
#         print(t_sets)
    tags_list = list(t_sets)
    
    stoplist = set(stopwords.words('english'))
    
    word_list = [i for i in tags_list if i not in stoplist]
    
    return tags_list

# %%
# tag list obtained from the dataset
# global tags_list

tags_list = ['dsu', 'trees', 'chinese remainder theorem', 'sortings', 'games', 'implementation', 'bitmasks',
              '*special', 'hashing', 'geometry', 'two pointers', 'combinatorics', 'flows', 'strings',
              'probabilities', 'data structures', 'ternary search', 'greedy', 'math', 'matrices',
              'divide and conquer', 'dfs and similar', 'constructive algorithms', 'brute force', 'dp',
              '2-sat', 'graph matchings', 'binary search', 'number theory', 'graphs', 'fft', 'shortest paths',
              'schedules', 'meet-in-the-middle', 'string suffix structures', 'expression parsing']

# %%
def plot_class_distribution(Y,classes):
    
    count_list = [0]*Y.shape[1]
    
    for index in range(Y.shape[1]):
        
        count_list[index] = np.sum(Y[:,index])/Y.shape[0]
    
    plt.figure(figsize=(8, 8), dpi=100)
    
    plt.barh(classes,count_list, align='center', alpha=0.5)
#     plt.bar(np.arange(Y.shape[1]),count_list, align='center', alpha=0.5)
#     plt.plot(np.arange(Y.shape[1]),count_list)
    plt.show()

# %%
def data_preprocessing():
    
    global X, Y, mlb, distinct_tags
    
    df = pd.read_csv("codeforces_question_v5.csv")
    df = df.drop(['id','name','author'],axis = 1)
    df = df[df.solution != "no code found"]
    df = df.dropna()
    print(df.shape)
    distinct_tags = get_all_distinct_tags(df["tags"])
    
    df["problem statement"] = [process_problem_statement(x) for x in df["problem statement"]]
#     df["solution"] = [process_problem_solution(x) for x in df["solution"]]
    df["time_taken"] = [process_time_taken(x) for x in df["time_taken"]]
    
#     X = copy.deepcopy(df["solution"]+df["time_taken"])
    X = copy.deepcopy(df["solution"])
#     X = copy.deepcopy(df["problem statement"])
    Y = [process_tags(distinct_tags,x) for x in df["tags"]]

    mlb = MultiLabelBinarizer()
    Y = mlb.fit_transform(Y)
    
    
    
    plot_class_distribution(Y,mlb.classes_)

# %%
data_preprocessing()
# Out:
# (39788, 6)

# %%
def reduce_sample_imbalance(X_train,Y_train):
    
    global X, Y, mlb, distinct_tags
    
    X_train = pd.DataFrame(X_train).values
    
    xtrain_col_index = X_train.shape[1]
    xtrain_row_index = X_train.shape[0]
    
    XY = np.column_stack((X_train,Y_train))
    
    labels = [0]*len(mlb.classes_)
    row_index_to_delete = []
    ratio = []
    
    for index in range(Y_train.shape[1]):
        ratio.append(np.sum(Y_train[:,index])/Y_train.shape[0])
        if np.sum(Y_train[:,index])/Y_train.shape[0] > 0.03:
            
            labels[index] = 1
            
    ratio.sort()

    count_deletions = [0]*len(labels)
    for index in range(len(labels)):
        if labels[index] == 1:

            count_deletions[index] = int(np.sum(Y_train[:,index]) * 0.97)    
    
    for index in range(Y_train.shape[0]):
        flag_to_delete = True
        
        for yindex in range(X_train.shape[1],XY.shape[1]):
            if Y_train[index][yindex-X_train.shape[1]] == 1:
                if labels[yindex-X_train.shape[1]] == 0 or count_deletions[yindex-X_train.shape[1]] <= 0:
                    flag_to_delete = False
                    break
        
        if flag_to_delete:
            row_index_to_delete.append(index)
            for i in range(len(count_deletions)):
                count_deletions[i] -= Y_train[index][i]
    
        if sum(count_deletions) <= 0:
            break;
            
    XY = np.delete(XY, row_index_to_delete,axis=0)
    
    ratio = []
    for index in range(X_train.shape[1],XY.shape[1]):
        ratio.append(np.sum(XY[:,index])/XY.shape[0])
    
    plot_class_distribution(XY[:,X_train.shape[1]:],mlb.classes_)
    
    
    data_to_repeat_index = [1]*XY.shape[0]
    labels = [0]*len(mlb.classes_)
    ratio = []
    for index in range(xtrain_col_index,XY.shape[1]):
        ratio.append(np.sum(XY[:,index])/XY.shape[0])
        if np.sum(XY[:,index])/XY.shape[0] < 0.02:
            labels[index-xtrain_col_index] = 1
    

    ratio.sort()
        
    for index in range(XY.shape[0]):
        for yindex in range(X_train.shape[1],XY.shape[1]):
            if XY[index][yindex] == 1 and labels[yindex-X_train.shape[1]] > 0:
                data_to_repeat_index[index] = 100
                labels[yindex-X_train.shape[1]] = -1
    
    XY = np.repeat(XY, repeats = data_to_repeat_index, axis=0)

    X_train = XY[:,0]
    Y_train = XY[:,1:]
            
    X_train = pd.Series(X_train)
    X_train = X_train.astype(str)
    Y_train = Y_train.astype('int') 
    return X_train,Y_train

# %%
def oversample_train_data(X_train,Y_train):
    
    global X, Y, mlb, distinct_tags
    
    X_train = pd.DataFrame(X_train).values
    
    XY = np.column_stack((X_train,Y_train))
    
    labels = []
    data_to_repeat_index = [1]*Y_train.shape[0]
    
    for index in range(Y_train.shape[1]):
        if np.sum(Y_train[:,index])/Y_train.shape[0] < 0.02:
            labels.append(index)
    
    for index in range(Y_train.shape[0]):
        for label in labels:
            if Y_train[index][label] == 1:
                data_to_repeat_index[index] = 200
    

    XY = np.repeat(XY, repeats = data_to_repeat_index, axis=0)
    
    X_train = XY[:,0]
    Y_train = XY[:,1:]
        
#     Ytrain = mlb.inverse_transform(Y_train)
    
#     print(Ytrain)
    
    X_train = pd.Series(X_train)
    X_train = X_train.astype(str)
    Y_train = Y_train.astype('int') 
    return X_train,Y_train

# %%
global X, Y, mlb, distinct_tags

X_train, X_validation, Y_train, Y_validation = train_test_split(X, Y, test_size = 0.2, random_state = 0)

plot_class_distribution(Y_train,mlb.classes_)
X_train,Y_train = reduce_sample_imbalance(X_train,Y_train)
plot_class_distribution(Y_train,mlb.classes_)
plot_class_distribution(Y_validation,mlb.classes_)

classifier = make_pipeline(
    CountVectorizer(ngram_range = (1,2),binary = True,lowercase=False),
    TfidfTransformer(norm = 'l2',sublinear_tf = True),
    OneVsRestClassifier(LinearSVC(penalty="l2",loss="squared_hinge",tol=1,random_state=0,max_iter=1000,C = 1)))

classifier.fit(X_train, Y_train)
predicted = classifier.predict(X_train)

# %%
print(Y_train.shape)
print(predicted.shape)
y_labels_predicted = mlb.inverse_transform(predicted)
y_labels_actual = mlb.inverse_transform(Y_train)

print("On Train data")
print("hamming_loss: ",hamming_loss(Y_train,predicted))
print("recall_score: ",recall_score(Y_train,predicted,average = 'weighted'))
print("precision_score: ",precision_score(Y_train,predicted,average = 'weighted'))
print("f1_score: ",f1_score(Y_train,predicted,average = 'weighted'))

print("roc_auc_score: ",roc_auc_score(Y_train,predicted,average = 'weighted'))

print()
print()

# print("Actual vs Predicted")

# for item, labels in zip(y_labels_actual, y_labels_predicted):
#         print('{0} => {1}'.format(item, ', '.join(labels)))

# print()
# print()


print("On Validation data")
predicted = classifier.predict(X_validation)

y_labels_predicted = mlb.inverse_transform(predicted)
y_labels_actual = mlb.inverse_transform(Y_validation)
# print(predicted)
print(Y_validation.shape)
print(predicted.shape)
print("hamming_loss: ",hamming_loss(Y_validation,predicted))
print("recall_score: ",recall_score(Y_validation,predicted,average = 'weighted'))
print("precision_score: ",precision_score(Y_validation,predicted,average = 'weighted'))
print("f1_score: ",f1_score(Y_validation,predicted,average = 'weighted'))


print()
print()

print("roc_auc_score: ",roc_auc_score(Y_validation,predicted,average = 'weighted'))
# print("confusion_matrix: ",confusion_matrix(Y_validation,predicted))

print()
print()
print("Actual vs Predicted")

for item, labels in zip(y_labels_actual, y_labels_predicted):
        print('{0} => {1}'.format(item, ', '.join(labels)))


# for col_index in range(Y_validation.shape[1]):
#     print(confusion_matrix(Y_validation[:,col_index],predicted[:,col_index]))
    
labels_list = mlb.classes_
roc_auc_list = []
for col_index in range(Y_validation.shape[1]):
    roc_auc_list.append(roc_auc_score(Y_validation[:,col_index],predicted[:,col_index]))

plt.figure(figsize=(8, 8), dpi=100)
plt.barh(labels_list,roc_auc_list, align='center', alpha=0.5)
plt.show()

################################################################################

metrics_list = []
recall_list = []
precision_list = []
roc_auc_list = []
f1_score_list = []

classes_list = mlb.classes_
    
for col_index in range(Y_validation.shape[1]):
    recall_list.append(recall_score(Y_validation[:,col_index],predicted[:,col_index]))
    
for col_index in range(Y_validation.shape[1]):
    precision_list.append(precision_score(Y_validation[:,col_index],predicted[:,col_index]))
    
for col_index in range(Y_validation.shape[1]):
    f1_score_list.append(f1_score(Y_validation[:,col_index],predicted[:,col_index]))
    
for col_index in range(Y_validation.shape[1]):
    roc_auc_list.append(roc_auc_score(Y_validation[:,col_index],predicted[:,col_index]))

metrics_list = [mlb,classes_list,recall_list,precision_list,f1_score_list,roc_auc_list,Y_validation,predicted]

with open('Linear_SVC_Codeforces', 'wb') as fp:
    pickle.dump(metrics_list, fp)

################################################################################
# Out:
# (31830, 36)
# (31830, 36)
# On Train data
# hamming_loss:  0.004744824938038887
# recall_score:  0.9450274058885807
# precision_score:  0.9816226383679485
# f1_score:  0.962702771247846
# roc_auc_score:  0.9696318876067691
#
#
# On Validation data
# (7958, 36)
# (7958, 36)
# hamming_loss:  0.015843595543268828
# recall_score:  0.8167536450207133
# precision_score:  0.9323613049728309
# f1_score:  0.8694578820595751
#
#
# roc_auc_score:  0.9006383620039062
#
#
# Actual vs Predicted
# ('bitmasks', 'combinatorics', 'dp', 'math', 'number theory') => bitmasks, combinatorics, dp, math, number theory
# ('dp', 'dsu', 'graphs') => dp, dsu, graphs
# ('dfs and similar', 'number theory', 'trees') => dfs and similar, number theory, trees
# ('two pointers',) => greedy
# ('binary search', 'constructive algorithms', 'data structures') => binary search, constructive algorithms, data structures
# ('binary search', 'math') => geometry
# ('binary search', 'greedy', 'implementation', 'sortings') => binary search, greedy, implementation, sortings
# ('implementation',) => implementation
# ('graphs', 'greedy', 'shortest paths') => graphs, greedy, shortest paths
# ('greedy', 'sortings') => greedy, sortings
# ('binary search', 'data structures', 'greedy', 'two pointers') => binary search, data structures, greedy, two pointers
# ('brute force', 'greedy', 'sortings') => brute force, greedy, sortings
# ('math',) => math
# ('binary search', 'data structures', 'sortings', 'two pointers') => binary search, data structures, sortings, two pointers
# ('bitmasks', 'dp', 'probabilities') => bitmasks, dp, probabilities
# ('dp',) => dp
# ('data structures',) =>
# ('data structures', 'geometry', 'math') => data structures, geometry, math
# ('flows',) => graphs
# ('implementation',) => implementation
# ('geometry',) => geometry
# ('brute force', 'greedy', 'implementation') =>
# ('greedy', 'implementation') => greedy, implementation
# ('dfs and similar', 'greedy', 'sortings', 'trees') => dfs and similar, greedy, sortings, trees
# ('brute force', 'implementation', 'strings') => brute force, implementation, strings
# ('implementation', 'strings') => implementation, strings
# ('data structures', 'number theory') => data structures
# ('binary search', 'data structures') => binary search, data structures
# ('constructive algorithms', 'greedy', 'math') => constructive algorithms, greedy, math
# ('dfs and similar', 'dp', 'graph matchings', 'greedy', 'sortings', 'two pointers') => dfs and similar, dp, graph matchings, greedy, sortings, two pointers
# ('dp', 'dsu', 'trees') => dp, dsu, trees
# ('math', 'sortings') => math, sortings
# ('bitmasks',) => bitmasks
# ('greedy', 'sortings') => constructive algorithms, implementation
# ('combinatorics', 'dfs and similar', 'dp', 'trees') => combinatorics, dfs and similar, dp, trees
# ('combinatorics', 'dp') => combinatorics, dp
# ('binary search', 'geometry') => binary search, geometry
# ('implementation', 'math') =>
# ('brute force', 'number theory', 'sortings') => greedy, sortings
# ('greedy', 'sortings') => greedy, sortings
# ('implementation',) => implementation
# ('brute force', 'implementation') => brute force, implementation
# ('binary search', 'dfs and similar', 'probabilities', 'sortings', 'trees') => binary search, dfs and similar, probabilities, sortings, trees
# ('implementation',) => implementation
# ('implementation',) => implementation
# ('fft', 'math') =>
# ('data structures', 'implementation', 'math') => data structures, implementation, math
# ('constructive algorithms', 'implementation') => constructive algorithms, implementation
# ('greedy',) => greedy
# ('graphs', 'greedy', 'shortest paths') => graphs, greedy, shortest paths
# ('implementation', 'strings') => implementation, strings
# ('data structures', 'implementation') =>
# ('greedy',) => greedy
# ('constructive algorithms', 'strings') => greedy, implementation
# ('graphs', 'shortest paths') => graphs, shortest paths
# ('data structures', 'dp', 'math', 'sortings') => binary search, greedy
# ('math', 'matrices') => math, matrices
# ('greedy',) => greedy
# ('math',) => math
# ('binary search', 'greedy', 'two pointers') => binary search, greedy, two pointers
# ('dp', 'greedy', 'implementation') => greedy, implementation, sortings
# ('combinatorics', 'dp') => combinatorics, dp
# ('data structures', 'dp') => data structures, dp
# ('dp', 'implementation') =>
# ('brute force', 'dp') => brute force, dp
# ('brute force', 'dp', 'greedy', 'math', 'number theory') => brute force, dp, greedy, math, number theory
# ('brute force', 'number theory', 'sortings') => greedy, sortings
# ('geometry',) => geometry
# ('brute force', 'math', 'number theory') => math, number theory
# ('binary search', 'combinatorics', 'two pointers') => binary search, combinatorics, two pointers
# ('geometry',) => geometry
# ('dfs and similar', 'trees') => dfs and similar, trees
# ('dp',) => dp
# ('implementation', 'strings') => implementation, strings
# ('binary search', 'data structures', 'dp') => binary search, data structures, dp
# ('bitmasks', 'brute force', 'graph matchings') => bitmasks, brute force, graph matchings
# ('brute force', 'math', 'number theory') => brute force, math, number theory
# ('brute force',) => brute force
# ('constructive algorithms',) => constructive algorithms
# ('brute force', 'dfs and similar', 'dsu') => brute force, dfs and similar, dsu
# ('constructive algorithms', 'greedy', 'math') => implementation
# ('dfs and similar', 'greedy', 'trees') => dfs and similar, greedy, trees
# ('brute force', 'strings') => brute force, strings
# ('greedy', 'math') =>
# ('data structures', 'divide and conquer', 'dp', 'math') => data structures, divide and conquer, dp, math
# ('binary search', 'implementation') => binary search, implementation
# ('data structures', 'dfs and similar', 'graphs', 'greedy', 'shortest paths') => greedy
# ('brute force', 'data structures', 'graphs') => data structures
# ('number theory',) => number theory
# ('brute force', 'number theory', 'trees') => brute force, number theory, trees
# ('binary search',) => binary search
# ('greedy',) => implementation, math, number theory
# ('brute force', 'combinatorics', 'constructive algorithms', 'math') => brute force, combinatorics, constructive algorithms, math
# ('implementation',) => implementation
# ('brute force', 'combinatorics', 'dp') => brute force, combinatorics, dp
# ('math',) => implementation, math
# ('implementation', 'strings') => implementation, strings
# ('dfs and similar', 'graphs', 'sortings') => dfs and similar, graphs, sortings
# ('greedy', 'sortings', 'two pointers') => greedy, sortings
# ('constructive algorithms', 'strings') => constructive algorithms, strings
# ('data structures',) => data structures
# ('brute force', 'combinatorics', 'greedy', 'math') => brute force
# ('combinatorics', 'dp') => combinatorics, dp
# ('brute force', 'geometry', 'implementation') => brute force, geometry, implementation
# ('brute force', 'constructive algorithms') => brute force, constructive algorithms
# ('binary search', 'brute force', 'greedy', 'implementation') => binary search, brute force, greedy, implementation
# ('data structures',) => data structures
# ('dfs and similar', 'shortest paths') => dfs and similar, shortest paths
# ('greedy',) => greedy, implementation
# ('implementation',) => brute force, implementation
# ('binary search', 'math') => binary search, math
# ('brute force', 'implementation') => brute force, implementation
# ('graphs', 'greedy', 'shortest paths') => graphs, greedy, shortest paths
# ('greedy', 'implementation') => greedy, implementation
# ('binary search', 'geometry', 'ternary search') => geometry
# ('brute force', 'implementation') => brute force, implementation
# ('brute force', 'geometry') => brute force, geometry
# ('brute force', 'implementation') => brute force, implementation
# ('dfs and similar', 'dp', 'graphs', 'shortest paths') => dfs and similar, dp, graphs, shortest paths
# ('binary search', 'flows', 'graphs') => binary search, flows, graphs
# ('implementation',) =>
# ('graphs',) => graphs
# ('divide and conquer', 'math', 'number theory', 'trees') => divide and conquer, math, number theory, trees
# ('brute force', 'math', 'strings') => brute force, math, strings
# ('implementation', 'math') => math, number theory, strings
# ('data structures', 'trees') => data structures
# ('dp',) => dp
# ('implementation', 'math') => implementation, math
# ('two pointers',) => two pointers
# ('dp', 'math') => dp, math
# ('two pointers',) => two pointers
# ('brute force', 'number theory', 'sortings') => greedy, sortings
# ('geometry', 'implementation', 'math') => geometry, implementation, math
# ('brute force', 'greedy', 'math') => brute force, greedy, math
# ('bitmasks', 'dp') => bitmasks, dp
# ('brute force', 'dp', 'number theory') => brute force, dp, number theory
# ('dp', 'greedy') => dp, greedy
# ('data structures', 'hashing', 'strings') => data structures, hashing, strings
# ('data structures', 'dp') => data structures, dp
# ('binary search', 'constructive algorithms', 'greedy', 'math') => greedy
# ('brute force', 'greedy') => implementation
# ('math',) => math
# ('greedy', 'implementation') => greedy, implementation
# ('probabilities', 'shortest paths') => math, probabilities
# ('greedy',) => greedy
# ('greedy',) => greedy
# ('data structures', 'dfs and similar') => data structures, dfs and similar
# ('implementation', 'math', 'matrices') => implementation, math, matrices
# ('implementation',) => implementation
# ('bitmasks', 'dp') => bitmasks, dp
# ('brute force', 'dfs and similar', 'graphs') => brute force, dfs and similar, graphs
# ('greedy',) => greedy
# ('implementation',) =>
# ('data structures', 'strings') => data structures, strings
# ('implementation', 'math') => implementation
# ('greedy',) => greedy
# ('number theory',) => number theory
# ('dp', 'graphs') => dp, graphs
# ('data structures', 'flows', 'graphs', 'trees') => dfs and similar, flows, graphs, trees
# ('games', 'greedy') => games, greedy
# ('data structures', 'sortings') => data structures, sortings
# ('binary search', 'implementation') => binary search, implementation
# ('brute force', 'strings') => brute force, strings
# ('shortest paths',) => shortest paths
# ('binary search', 'data structures') => binary search, data structures
# ('dp', 'strings') => dp, strings
# ('combinatorics', 'dsu', 'graphs') => combinatorics, dsu, graphs
# ('greedy',) => greedy
# ('brute force', 'sortings') => brute force, sortings
# ('dp', 'sortings') => dp, sortings
# ('implementation', 'math') => implementation, math
# ('data structures', 'divide and conquer', 'dp') => data structures, divide and conquer, dp
# ('brute force', 'implementation') => brute force, implementation
# ('expression parsing', 'implementation') => expression parsing, implementation
# ('implementation', 'strings') => implementation, strings
# ('bitmasks', 'dfs and similar', 'dsu', 'graphs') => bitmasks, dfs and similar, dsu, graphs
# ('brute force', 'number theory') => brute force, number theory
# ('constructive algorithms', 'dfs and similar', 'dp', 'graphs', 'greedy', 'sortings', 'trees') => data structures, implementation, sortings, trees
# ('graphs', 'greedy', 'shortest paths') => graphs, greedy, shortest paths
# ('dfs and similar', 'dp', 'graphs', 'shortest paths') => dfs and similar, dp, graphs, shortest paths
# ('math',) => math
# ('math', 'number theory') => math, number theory
# ('implementation', 'strings') => implementation, strings
# ('hashing', 'number theory') =>
# ('implementation', 'strings') => implementation, strings
# ('constructive algorithms', 'dp') => constructive algorithms, dp
# ('brute force', 'data structures', 'dsu', 'trees') => data structures, sortings
# ('strings',) => strings
# ('brute force', 'combinatorics') => brute force, combinatorics
# ('greedy', 'sortings') => greedy, sortings
# ('binary search', 'bitmasks', 'brute force', 'greedy', 'implementation', 'strings') => implementation, strings
# ('brute force', 'constructive algorithms') => brute force, constructive algorithms
# ('brute force',) => brute force
# ('data structures', 'greedy') => data structures, greedy
# ('binary search', 'geometry', 'ternary search') => binary search, geometry, ternary search
# ('binary search', 'math') => binary search, math
# ('games',) => implementation, math
# ('bitmasks', 'combinatorics', 'number theory') => dp
# ('geometry',) => geometry
# ('constructive algorithms', 'greedy') => constructive algorithms, greedy
# ('data structures', 'greedy', 'sortings') => data structures, greedy, sortings
# ('dfs and similar', 'graphs', 'implementation', 'shortest paths') => dfs and similar, graphs, implementation, shortest paths
# ('combinatorics', 'dp', 'probabilities') => combinatorics, dp, probabilities
# ('data structures', 'implementation', 'math') => data structures, implementation, math
# ('combinatorics', 'implementation', 'math') => combinatorics, implementation, math
# ('binary search', 'data structures', 'dp', 'hashing', 'strings') => binary search, data structures, dp, hashing, strings
# ('data structures', 'strings') => data structures, strings
# ('combinatorics', 'sortings') => combinatorics, dp
# ('implementation',) => implementation
# ('implementation',) => implementation
# ('dp', 'dsu', 'graphs') => dp, dsu, graphs
# ('constructive algorithms', 'math') => constructive algorithms, math
# ('geometry',) => geometry
# ('implementation', 'math') => greedy, implementation
# ('combinatorics', 'number theory') => combinatorics, number theory
# ('data structures', 'greedy', 'hashing', 'strings') => data structures, greedy, hashing, strings
# ('brute force', 'math') => brute force, math
# ('brute force', 'implementation', 'math') => brute force, implementation, math
# ('dp', 'math', 'probabilities') => dp, math, probabilities
# ('bitmasks', 'brute force', 'divide and conquer', 'graphs') => brute force, divide and conquer, graphs
# ('strings',) => strings
# ('math', 'number theory') => implementation
# ('brute force', 'math', 'strings') => brute force, math, strings
# ('math',) => implementation
# ('bitmasks', 'combinatorics', 'dp', 'math') => bitmasks, combinatorics, dp, math
# ('brute force', 'probabilities') => brute force
# ('dfs and similar', 'graphs') => dfs and similar, graphs
# ('implementation', 'math', 'sortings') => implementation, math, sortings
# ('greedy', 'sortings') => greedy, sortings
# ('dp',) => dp
# ('implementation', 'math') => implementation, math
# ('dp', 'greedy', 'implementation') => dp, greedy, implementation
# ('implementation', 'math', 'sortings') => implementation, math, sortings
# ('dp',) => dp
# ('binary search', 'data structures', 'implementation') => binary search, data structures, implementation
# ('brute force', 'dfs and similar', 'dsu') => brute force, dfs and similar, dsu
# ('binary search', 'combinatorics', 'constructive algorithms', 'implementation', 'math') => binary search, combinatorics, constructive algorithms, implementation, math
# ('dp', 'implementation') => dp, implementation
# ('combinatorics', 'math') => combinatorics, math
# ('greedy', 'implementation') => greedy, implementation
# ('combinatorics', 'dp', 'probabilities') => math
# ('data structures',) => data structures, sortings
# ('bitmasks', 'probabilities') => bitmasks, probabilities
# ('greedy', 'math') => greedy, math
# ('math',) => combinatorics, dp, math
# ('data structures',) => data structures
# ('implementation', 'sortings') => implementation, sortings
# ('implementation',) => implementation
# ('math', 'number theory') => math
# ('brute force', 'implementation') => brute force, implementation
# ('dfs and similar', 'dsu', 'math') => dfs and similar, dsu, math
# ('hashing', 'string suffix structures', 'strings') => hashing, string suffix structures, strings
# ('dp', 'greedy', 'sortings') => dp, greedy, sortings
# ('flows',) =>
# ('dp', 'greedy') => dp, greedy
# ('data structures', 'implementation') => data structures
# ('ternary search',) => ternary search
# ('binary search',) => binary search
# ('data structures', 'dfs and similar', 'sortings') => data structures, dfs and similar, sortings
# ('implementation', 'math') => implementation, math
# ('dp', 'implementation', 'trees') => dp, implementation, trees
# ('data structures', 'trees') => data structures, trees
# ('brute force',) => brute force
# ('data structures', 'implementation') => data structures, implementation
# ('constructive algorithms', 'math', 'number theory') => math
# ('flows',) => flows
# ('combinatorics', 'dp') => combinatorics, dp
# ('constructive algorithms',) => constructive algorithms
# ('constructive algorithms', 'geometry') => constructive algorithms, math, number theory
# ('greedy', 'math') => greedy, math
# ('bitmasks',) => bitmasks
# ('brute force', 'math') => brute force, math
# ('bitmasks', 'constructive algorithms', 'number theory') => bitmasks, constructive algorithms, number theory
# ('dfs and similar', 'implementation') => dfs and similar, implementation
# ('implementation',) => implementation
# ('combinatorics', 'math') => combinatorics, math
# ('brute force', 'greedy', 'sortings') => implementation
# ('binary search', 'two pointers') => binary search, greedy
# ('dp', 'strings', 'two pointers') => dp, strings, two pointers
# ('dp', 'implementation') => dp, implementation
# ('math', 'number theory') => math, number theory
# ('constructive algorithms', 'data structures', 'graphs', 'sortings') => data structures
# ('binary search', 'data structures', 'trees') => binary search, data structures, trees
# ('greedy', 'math') => greedy, math
# ('flows',) => flows
# ('dp',) => dp
# ('implementation',) => implementation
# ('implementation', 'math') => implementation, math
# ('math', 'strings') => math, strings
# ('dsu', 'implementation') => dsu, implementation
# ('binary search', 'bitmasks', 'brute force', 'dp', 'meet-in-the-middle') => binary search, bitmasks, brute force, dp, meet-in-the-middle
# ('greedy', 'sortings') => greedy, sortings
# ('brute force', 'dsu', 'math') => brute force, dsu, math
# ('bitmasks', 'brute force', 'dp', 'graphs') => dp
# ('binary search', 'sortings', 'two pointers') => binary search, sortings, two pointers
# ('greedy', 'implementation') => greedy, implementation
# ('brute force', 'math') => math
# ('two pointers',) => two pointers
# ('geometry', 'implementation') => geometry, implementation
# ('bitmasks', 'combinatorics', 'dp', 'implementation') => bitmasks, combinatorics, dp, implementation
# ('implementation',) => implementation
# ('data structures', 'implementation', 'string suffix structures', 'two pointers') => data structures, implementation, string suffix structures, two pointers
# ('geometry', 'math') => geometry, math
# ('data structures', 'greedy') => data structures, greedy
# ('constructive algorithms',) => constructive algorithms
# ('dp', 'implementation', 'trees') => dp, implementation, trees
# ('greedy', 'implementation') => greedy
# ('dp', 'greedy') => dp, greedy
# ('dfs and similar', 'dp', 'trees') => dfs and similar, dp, trees
# ('data structures', 'dp', 'greedy') => data structures, dp, greedy
# ('sortings',) => sortings
# ('greedy',) => greedy
# ('data structures', 'sortings') => sortings
# ('two pointers',) => two pointers
# ('dp',) => dp
# ('constructive algorithms', 'math') => implementation
# ('dfs and similar', 'dp', 'dsu', 'graphs', 'implementation', 'trees') => dfs and similar, dp, dsu, graphs, implementation, trees
# ('binary search', 'data structures', 'dp', 'hashing', 'sortings', 'string suffix structures', 'strings') => dp
# ('greedy',) =>
# ('data structures', 'implementation') => data structures, implementation
# ('implementation',) => implementation
# ('dfs and similar', 'graphs', 'sortings') => greedy
# ('probabilities',) => probabilities
# ('binary search', 'constructive algorithms', 'dfs and similar', 'graphs', 'greedy', 'trees') => binary search, constructive algorithms, dfs and similar, graphs, greedy, trees
# ('constructive algorithms', 'dp', 'math', 'number theory') => constructive algorithms, dp, math, number theory
# ('data structures', 'greedy') => data structures, greedy
# ('implementation',) => implementation
# ('greedy', 'sortings') => implementation
# ('combinatorics', 'graphs', 'math') => combinatorics, graphs, math
# ('binary search', 'brute force', 'data structures', 'implementation') => binary search, brute force, data structures, implementation
# ('implementation',) => implementation
# ('implementation',) => implementation
# ('constructive algorithms',) => constructive algorithms
# ('combinatorics', 'dfs and similar', 'graphs', 'trees') => combinatorics, dfs and similar, graphs, trees
# ('constructive algorithms', 'implementation') => constructive algorithms, implementation
# ('constructive algorithms', 'implementation') => constructive algorithms, implementation
# ('dfs and similar', 'strings', 'trees') => dfs and similar, strings, trees
# ('strings',) => implementation
# ('strings',) => strings
# ('implementation',) => implementation
# ('math', 'number theory') => math, number theory
# ('binary search',) =>
# ('binary search',) => binary search
# ('brute force', 'dp') => brute force, dp
# ('constructive algorithms', 'dfs and similar') => constructive algorithms, dfs and similar
# ('geometry', 'math') => greedy
# ('brute force', 'combinatorics', 'dp') => brute force, combinatorics, dp
# ('games', 'math') => math
# ('brute force', 'implementation') => brute force, implementation
# ('brute force', 'dp') => greedy
# ('dfs and similar', 'dp', 'graphs', 'strings', 'trees') => data structures, dfs and similar, dp, trees
# ('two pointers',) =>
# ('bitmasks', 'combinatorics', 'dp', 'math', 'number theory') => bitmasks, combinatorics, dp, math, number theory
# ('bitmasks', 'brute force') => greedy
# ('data structures', 'hashing', 'strings') => data structures, hashing, strings
# ('data structures',) => data structures
# ('implementation',) => implementation, math
# ('binary search', 'constructive algorithms', 'greedy', 'math') =>
# ('greedy',) => greedy
# ('sortings', 'two pointers') => sortings, two pointers
# ('dsu', 'math') =>
# ('brute force', 'implementation') => implementation, math
# ('data structures',) => data structures
# ('data structures', 'dp', 'math', 'sortings') => binary search, data structures, sortings
# ('binary search', 'math') => binary search, math
# ('expression parsing',) => greedy
# ('dp', 'dsu', 'graphs') => dp, dsu, graphs
# ('*special',) => *special
# ('data structures', 'dsu') => data structures
# ('data structures', 'sortings') => data structures, sortings
# ('brute force', 'implementation') => brute force, implementation
# ('dfs and similar', 'dsu', 'graphs', 'math', 'trees') => combinatorics, dfs and similar, dsu, graphs, math
# ('brute force', 'greedy', 'sortings') => brute force, greedy, sortings
# ('constructive algorithms', 'data structures', 'dfs and similar', 'dp', 'graphs') => constructive algorithms, data structures, dfs and similar, dp, graphs
# ('dp', 'dsu', 'trees') => dp, dsu, trees
# ('brute force', 'number theory', 'sortings') => greedy, sortings
# ('brute force', 'graphs', 'math') => implementation, math
# ('dp',) => dp
# ('data structures', 'greedy', 'implementation') =>
# ('combinatorics', 'dp') => combinatorics, dp
# ('dp',) => dp
# ('bitmasks', 'constructive algorithms', 'dp', 'greedy') => bitmasks, constructive algorithms, dp, greedy
# ('dp', 'greedy', 'implementation') => dp, greedy, implementation
# ('dp', 'math', 'number theory') => dp, math, number theory
# ('data structures', 'sortings') => data structures, sortings
# ('brute force', 'games', 'implementation') => brute force, games, implementation
# ('dfs and similar', 'dp', 'graphs', 'greedy') => dfs and similar, dp, graphs, greedy
# ('dfs and similar', 'dp', 'graphs', 'shortest paths') => dfs and similar, dp, graphs, shortest paths
# ('brute force', 'combinatorics', 'dp', 'math', 'trees') => dp, math
# ('math',) => math
# ('binary search', 'implementation') => binary search, implementation
# ('data structures', 'dsu', 'trees') => data structures, dsu, trees
# ('dsu', 'implementation') =>
# ('combinatorics', 'number theory') => combinatorics, number theory
# ('dfs and similar', 'divide and conquer') => dfs and similar, divide and conquer
# ('data structures', 'implementation', 'math') => implementation, math
# ('constructive algorithms', 'math', 'number theory') => greedy, math
# ('brute force', 'dp', 'implementation') => brute force, dp, implementation
# ('geometry',) => geometry
# ('bitmasks', 'constructive algorithms') => math
# ('greedy', 'sortings') => greedy, sortings
# ('combinatorics', 'dp') => combinatorics, dp
# ('data structures', 'number theory') => data structures, number theory
# ('number theory',) => number theory
# ('greedy', 'sortings') => greedy, sortings
# ('binary search', 'geometry', 'implementation', 'two pointers') => binary search, geometry, implementation, two pointers
# ('brute force', 'implementation', 'sortings') => brute force, implementation, sortings
# ('constructive algorithms', 'graph matchings', 'greedy', 'math') => constructive algorithms, graph matchings, greedy
# ('dp', 'strings') => combinatorics, dp
# ('data structures', 'dp') => brute force, dfs and similar
# ('constructive algorithms', 'implementation') => constructive algorithms, implementation
# ('brute force', 'implementation') => implementation
# ('data structures', 'dfs and similar', 'sortings') => data structures, dfs and similar, sortings
# ('data structures', 'geometry') => data structures, geometry
# ('bitmasks', 'graph matchings', 'graphs') => bitmasks, graph matchings, graphs
# ('dp', 'graph matchings', 'greedy') => dp, graph matchings, greedy
# ('implementation',) => implementation
# ('dfs and similar', 'dsu', 'graphs', 'sortings') => dfs and similar, dsu, graphs, sortings
# ('brute force', 'constructive algorithms') => brute force, constructive algorithms
# ('constructive algorithms', 'greedy') => constructive algorithms, greedy
# ('implementation',) => implementation
# ('binary search', 'brute force', 'data structures', 'implementation', 'sortings', 'two pointers') => binary search, brute force, data structures, implementation, sortings, two pointers
# ('greedy',) => implementation
# ('constructive algorithms', 'implementation') => constructive algorithms, implementation
# ('implementation',) => constructive algorithms
# ('dfs and similar', 'graphs', 'implementation') => dfs and similar, graphs, implementation
# ('brute force', 'greedy', 'implementation') => implementation
# ('dfs and similar', 'dsu', 'greedy') => dfs and similar, dsu, greedy
# ('implementation', 'math') => implementation, math
# ('data structures', 'trees') => data structures, trees
# ('*special', 'dfs and similar', 'graphs', 'greedy') => *special, dfs and similar, graphs, greedy
# ('bitmasks', 'math', 'number theory') => bitmasks, math, number theory
# ('chinese remainder theorem', 'fft', 'math') => chinese remainder theorem, fft
# ('greedy', 'implementation', 'math') =>
# ('brute force', 'dp') => brute force, dp
# ('binary search', 'data structures', 'two pointers') =>
# ('data structures', 'divide and conquer', 'trees') => data structures, divide and conquer, trees
# ('binary search', 'hashing', 'strings', 'two pointers') => binary search, hashing, strings, two pointers
# ('dp', 'greedy', 'implementation') => dp, greedy, implementation
# ('data structures', 'implementation') => data structures, implementation
# ('constructive algorithms', 'graphs', 'implementation') => graphs, implementation
# ('brute force', 'implementation', 'number theory') => implementation, number theory
# ('math',) => math
# ('brute force', 'number theory', 'sortings') => brute force, greedy, sortings
# ('dfs and similar', 'divide and conquer') => dfs and similar, divide and conquer
# ('binary search', 'data structures', 'greedy', 'two pointers') => binary search, data structures, greedy, two pointers
# ('flows', 'graph matchings') => flows, graph matchings
# ('binary search', 'graphs') => binary search, graphs
# ('brute force', 'implementation', 'two pointers') =>
# ('number theory',) => number theory
# ('data structures', 'number theory') => implementation, math, number theory
# ('brute force', 'implementation', 'math') => greedy, implementation
# ('binary search', 'geometry') => binary search, geometry
# ('greedy', 'two pointers') =>
# ('dfs and similar', 'shortest paths') => dfs and similar, shortest paths
# ('data structures', 'greedy', 'sortings') => data structures, greedy, sortings
# ('greedy', 'sortings') => greedy, sortings
# ('dp',) => implementation
# ('brute force', 'dp') =>
# ('divide and conquer', 'dp', 'dsu', 'number theory', 'trees') => trees
# ('dp', 'sortings') => data structures
# ('probabilities',) => probabilities
# ('combinatorics', 'graphs', 'trees') => combinatorics, graphs, trees
# ('sortings',) => sortings
# ('dp',) => dp
# ('brute force', 'combinatorics', 'data structures', 'geometry', 'math', 'sortings') => brute force, combinatorics, geometry, math, sortings
# ('combinatorics', 'dp', 'probabilities') => combinatorics, dp, probabilities
# ('dfs and similar', 'graphs', 'hashing', 'shortest paths') => dfs and similar, graphs, hashing, shortest paths
# ('implementation', 'strings') => implementation, strings
# ('implementation',) => implementation
# ('dp', 'greedy', 'math', 'probabilities') => geometry, probabilities
# ('dp',) => dp
# ('greedy',) => implementation
# ('implementation',) => implementation
# ('implementation',) => implementation
# ('brute force', 'dp', 'number theory') => math
# ('dfs and similar', 'dsu', 'greedy') => dsu, greedy
# ('brute force', 'implementation') => implementation
# ('binary search', 'data structures', 'dp', 'two pointers') => binary search, data structures, dp, two pointers
# ('implementation', 'math') => strings
# ('greedy',) =>
# ('greedy', 'math', 'number theory') => greedy, math, number theory
# ('brute force', 'dfs and similar', 'graphs') => brute force, dfs and similar, graphs
# ('binary search', 'implementation', 'math') => binary search, implementation, math
# ('constructive algorithms',) => constructive algorithms, greedy
# ('combinatorics', 'probabilities') => math
# ('dfs and similar', 'dsu', 'greedy', 'shortest paths') => dfs and similar, dsu, greedy, shortest paths
# ('geometry', 'math') => geometry, math
# ('bitmasks', 'brute force', 'fft') => bitmasks, brute force, fft
# ('brute force', 'implementation', 'strings') => brute force, implementation, strings
# ('geometry', 'graphs', 'implementation', 'shortest paths') => geometry, graphs, implementation, shortest paths
# ('combinatorics', 'math') => combinatorics, dp, math
# ('sortings', 'strings') => sortings, strings
# ('binary search', 'dp', 'sortings', 'two pointers') => binary search, dp, sortings, two pointers
# ('bitmasks', 'brute force', 'divide and conquer', 'graphs') => graphs, greedy
# ('hashing', 'string suffix structures', 'strings') => hashing, string suffix structures, strings
# ('constructive algorithms', 'number theory') => constructive algorithms, number theory
# ('implementation',) => implementation
# ('implementation', 'math') => implementation, math
# ('greedy',) => greedy
# ('greedy', 'implementation') => greedy, implementation
# ('implementation',) => implementation
# ('dfs and similar', 'dp', 'greedy') => dfs and similar, dp, greedy
# ('implementation',) => implementation
# ('data structures', 'dsu', 'trees') => data structures, dsu, trees
# ('implementation', 'math', 'probabilities', 'trees') => dfs and similar, trees
# ('dp',) => combinatorics, dp, math
# ('binary search', 'greedy', 'two pointers') => binary search, greedy, two pointers
# ('implementation', 'strings') => greedy
# ('data structures', 'geometry', 'sortings') => data structures, geometry, sortings
# ('greedy', 'implementation', 'math') => greedy, implementation, math
# ('bitmasks', 'divide and conquer', 'dp') => bitmasks, divide and conquer, dp
# ('math',) => math
# ('dp', 'math') => dp, math
# ('greedy', 'implementation') =>
# ('brute force', 'number theory', 'sortings') => brute force, number theory, sortings
# ('binary search', 'implementation') => binary search, implementation
# ('binary search', 'data structures', 'implementation', 'sortings') => binary search, data structures, implementation, sortings
# ('implementation',) => implementation
# ('constructive algorithms', 'data structures', 'graphs', 'sortings') => data structures
# ('implementation',) => implementation
# ('dp', 'math', 'number theory', 'probabilities') => dp, math, number theory, probabilities
# ('implementation',) => implementation
# ('constructive algorithms',) => constructive algorithms
# ('dfs and similar', 'dp', 'greedy') => dfs and similar, dp, greedy
# ('greedy',) => greedy
# ('combinatorics', 'number theory') => combinatorics, number theory
# ('expression parsing', 'implementation') => expression parsing, implementation
# ('math',) => math
# ('constructive algorithms', 'data structures', 'greedy', 'sortings', 'trees') => constructive algorithms, data structures, greedy, sortings, trees
# ('bitmasks', 'combinatorics', 'dp', 'math', 'number theory', 'shortest paths') => bitmasks, combinatorics, dp, math, number theory, shortest paths
# ('brute force', 'constructive algorithms') => brute force, constructive algorithms
# ('bitmasks', 'combinatorics', 'dp') => dp
# ('dfs and similar', 'graphs', 'shortest paths') => dfs and similar, graphs, shortest paths
# ('data structures', 'hashing', 'strings') => data structures, hashing, strings
# ('dp', 'implementation', 'sortings') => implementation, sortings
# ('implementation',) => implementation, math
# ('brute force',) => implementation
# ('constructive algorithms', 'implementation') => constructive algorithms, implementation
# ('brute force', 'dfs and similar', 'graphs', 'hashing') => brute force, dfs and similar, graphs, hashing
# ('brute force', 'graphs', 'math') => math
# ('implementation',) =>
# ('greedy', 'strings') => greedy, strings
# ('data structures',) => data structures
# ('greedy',) => math
# ('dp', 'implementation', 'trees') => dp, implementation, trees
# ('brute force', 'greedy', 'implementation') => implementation
# ('graphs',) => constructive algorithms
# ('bitmasks', 'combinatorics', 'dp', 'implementation') => bitmasks, combinatorics, dp, implementation
# ('constructive algorithms', 'dfs and similar', 'graphs') => constructive algorithms, dfs and similar, graphs
# ('data structures', 'dfs and similar', 'trees') => data structures, dfs and similar, trees
# ('data structures', 'implementation', 'math') => implementation, math
# ('binary search',) =>
# ('brute force', 'implementation') => brute force, implementation
# ('data structures', 'number theory') => data structures, number theory
# ('binary search', 'data structures') =>
# ('binary search', 'implementation', 'math', 'sortings') => binary search, implementation, math, sortings
# ('brute force', 'implementation') => implementation
# ('brute force', 'math') => brute force, math
# ('binary search', 'dp') => binary search
# ('brute force', 'greedy', 'sortings') => brute force, greedy, sortings
# ('data structures', 'greedy') => data structures, greedy
# ('data structures', 'flows', 'graph matchings', 'trees') => data structures
# ('math',) => math
# ('math', 'ternary search') => math, ternary search
# ('dsu', 'graphs', 'shortest paths', 'sortings') => dfs and similar, dsu, graphs
# ('dp', 'implementation') => dp, implementation
# ('data structures', 'divide and conquer', 'greedy', 'math') =>
# ('games', 'math', 'number theory') => games, math
# ('math',) => math
# ('constructive algorithms', 'greedy', 'strings') => constructive algorithms
# ('data structures', 'string suffix structures') => data structures, string suffix structures
# ('math', 'matrices') => math, matrices
# ('data structures', 'probabilities') => data structures, probabilities
# ('brute force', 'combinatorics', 'dp', 'greedy', 'math') => brute force, combinatorics, dp, greedy, math
# ('sortings',) => sortings
# ('implementation',) => implementation
# ('data structures', 'dfs and similar', 'graphs', 'trees') => data structures, dfs and similar, graphs, trees
# ('binary search', 'math') => binary search, math
# ('implementation',) => implementation
# ('data structures', 'divide and conquer', 'implementation', 'trees') => data structures, trees
# ('geometry',) => geometry
# ('sortings',) => sortings
# ('binary search', 'greedy', 'strings') => binary search, greedy, strings
# ('*special',) => implementation, math
# ('constructive algorithms', 'implementation') => constructive algorithms, implementation
# ('dp', 'math') => dp, math
# ('brute force', 'constructive algorithms', 'math') => brute force, constructive algorithms, math
# ('bitmasks', 'combinatorics', 'number theory') => bitmasks, combinatorics, number theory
# ('brute force', 'implementation') => greedy
# ('combinatorics', 'dp', 'math') => combinatorics, dp, math
# ('data structures',) => data structures
# ('data structures',) => data structures
# ('binary search', 'geometry') => binary search, geometry
# ('combinatorics', 'dp', 'matrices', 'strings') => combinatorics, dp, matrices, strings
# ('data structures', 'dfs and similar', 'graphs', 'greedy') => data structures, dfs and similar, graphs, greedy
# ('brute force', 'probabilities') =>
# ('binary search', 'implementation', 'math') =>
# ('math',) => implementation, math
# ('implementation',) => implementation
# ('data structures',) => data structures
# ('brute force', 'dfs and similar', 'implementation') => implementation
# ('math', 'probabilities', 'trees') => probabilities, trees
# ('implementation',) => implementation
# ('implementation',) => implementation
# ('data structures', 'dsu', 'trees') => data structures, trees
# ('math', 'number theory') => math, number theory
# ('data structures', 'divide and conquer') => data structures, divide and conquer
# ('bitmasks', 'dp') => bitmasks, dp
# ('math',) => implementation
# ('constructive algorithms', 'greedy') => constructive algorithms, greedy
# ('implementation', 'math') => implementation, math
# ('greedy',) => greedy
# ('dp',) => dp
# ('implementation',) => strings
# ('dp', 'math', 'matrices') => dp, math, matrices
# ('implementation', 'math') => implementation, math
# ('implementation', 'strings') =>
# ('data structures',) => data structures
# ('*special', 'implementation') => greedy, implementation
# ('constructive algorithms', 'greedy', 'implementation') => constructive algorithms, greedy, implementation
# ('constructive algorithms', 'greedy', 'implementation') => constructive algorithms, greedy, implementation
# ('dfs and similar', 'dp', 'graphs', 'shortest paths') => dfs and similar, dp, graphs, shortest paths
# ('constructive algorithms', 'implementation', 'math') => constructive algorithms, implementation, math
# ('brute force', 'implementation') => dp
# ('brute force', 'implementation') => implementation
# ('brute force', 'constructive algorithms') => brute force, constructive algorithms
# ('constructive algorithms', 'implementation', 'math', 'trees') => dfs and similar, graphs, trees
# ('2-sat', 'dfs and similar', 'dsu', 'graphs') => 2-sat, dfs and similar, dsu, graphs
# ('data structures', 'greedy') => data structures, greedy
# ('greedy', 'sortings') => greedy, implementation, sortings
# ('dsu', 'graphs', 'shortest paths', 'sortings') => dsu, graphs, sortings
# ('dfs and similar', 'dp', 'dsu', 'ternary search', 'trees') => dfs and similar, dp, dsu, ternary search, trees
# ('greedy', 'implementation') => greedy, implementation
# ('data structures', 'greedy') => brute force
# ('binary search', 'geometry') => binary search, geometry
# ('brute force', 'data structures', 'implementation', 'math') => brute force, data structures, implementation, math
# ('shortest paths',) => shortest paths
# ('combinatorics', 'number theory') => combinatorics, number theory
# ('dp',) => dp
# ('number theory',) => number theory
# ('constructive algorithms', 'greedy', 'strings') => greedy, strings
# ('data structures', 'greedy', 'trees') => data structures, greedy, trees
# ('graphs',) => graphs
# ('binary search', 'constructive algorithms', 'dfs and similar', 'graphs', 'greedy', 'trees') => binary search, constructive algorithms, dfs and similar, graphs, greedy, trees
# ('geometry', 'implementation') => geometry, implementation
# ('implementation', 'strings') => implementation, strings
# ('binary search', 'bitmasks', 'combinatorics', 'data structures', 'divide and conquer') => binary search, bitmasks, combinatorics, data structures, divide and conquer
# ('data structures', 'dp') => data structures, dp
# ('binary search', 'greedy') => data structures, greedy
# ('brute force', 'dp') => brute force, dp
# ('constructive algorithms', 'math') => constructive algorithms, implementation, math
# ('dfs and similar',) => dfs and similar
# ('bitmasks', 'dp', 'games') => bitmasks, dp, games
# ('implementation',) => implementation
# ('brute force', 'geometry', 'math') => math
# ('implementation',) =>
# ('bitmasks', 'brute force', 'dp', 'graphs') => bitmasks, brute force, dp, graphs
# ('dfs and similar', 'graphs', 'shortest paths') => dfs and similar, graphs, shortest paths
# ('brute force',) => implementation
# ('implementation',) => implementation
# ('constructive algorithms',) => constructive algorithms
# ('binary search', 'brute force', 'greedy', 'implementation') => binary search, brute force, greedy, implementation
# ('brute force', 'greedy', 'implementation') => brute force, greedy, implementation
# ('data structures', 'implementation', 'sortings') => data structures, implementation, sortings
# ('binary search', 'sortings', 'ternary search', 'two pointers') => binary search, dp
# ('brute force', 'dp', 'number theory') => brute force, dp
# ('implementation',) => implementation, math
# ('dp',) => dp
# ('fft', 'math') => fft, math
# ('binary search', 'data structures', 'divide and conquer', 'dp', 'two pointers') =>
# ('combinatorics', 'greedy', 'math', 'number theory', 'sortings') => combinatorics, greedy, math, sortings
# ('binary search', 'brute force', 'constructive algorithms', 'greedy', 'sortings') => binary search, brute force, constructive algorithms, greedy, sortings
# ('constructive algorithms', 'math') => constructive algorithms
# ('data structures', 'dp') => data structures, dp
# ('constructive algorithms', 'math') => constructive algorithms, implementation
# ('sortings',) => greedy, sortings
# ('implementation', 'math') => math
# ('greedy', 'implementation') => greedy, implementation
# ('dp', 'implementation') => dp, implementation
# ('dp', 'math') => dp, math
# ('constructive algorithms',) => constructive algorithms
# ('greedy', 'math') => greedy, math
# ('dp', 'probabilities') => dp, probabilities
# ('constructive algorithms', 'math') =>
# ('graphs', 'sortings') => graphs, sortings
# ('games',) => games
# ('constructive algorithms', 'graphs', 'implementation') => constructive algorithms, graphs, implementation
# ('dfs and similar', 'dp', 'graphs', 'probabilities', 'trees') => dfs and similar, dp, graphs, probabilities, trees
# ('constructive algorithms', 'greedy') => constructive algorithms, greedy
# ('greedy', 'implementation', 'math') => implementation, math
# ('dp', 'math', 'matrices') => dp, math, matrices
# ('math', 'matrices', 'probabilities') => math, matrices, probabilities
# ('bitmasks', 'brute force', 'dfs and similar', 'expression parsing', 'implementation') => bitmasks, brute force, dfs and similar, expression parsing, implementation
# ('data structures', 'divide and conquer', 'trees') => data structures, divide and conquer, trees
# ('brute force', 'implementation') => brute force, implementation
# ('dfs and similar', 'dp', 'dsu', 'graphs', 'greedy') => dsu, graphs, sortings
# ('dp', 'probabilities') => dp, greedy, probabilities
# ('implementation',) => implementation
# ('brute force',) => dp
# ('greedy', 'implementation') => implementation
# ('data structures', 'implementation') =>
# ('hashing', 'string suffix structures', 'strings') => hashing, string suffix structures, strings
# ('implementation', 'math', 'number theory') => implementation, math, number theory
# ('brute force', 'geometry') => brute force, geometry
# ('dp', 'greedy') => dp, greedy
# ('math',) => math
# ('data structures', 'strings', 'trees') => data structures, strings, trees
# ('dfs and similar', 'dp', 'dsu', 'implementation', 'sortings', 'trees') => dfs and similar, dp, dsu, implementation, sortings, trees
# ('binary search', 'sortings', 'two pointers') => binary search, sortings, two pointers
# ('data structures', 'dp', 'matrices', 'strings') => dp, matrices, strings
# ('greedy', 'implementation') => greedy, implementation
# ('implementation', 'math') => math
# ('bitmasks', 'brute force', 'constructive algorithms', 'implementation', 'math') => bitmasks, brute force, constructive algorithms, implementation, math
# ('combinatorics', 'dp') =>
# ('implementation',) =>
# ('math', 'matrices', 'probabilities') => math, matrices, probabilities
# ('binary search', 'data structures', 'dfs and similar', 'dp', 'trees') => dfs and similar, graphs, trees
# ('binary search', 'dsu', 'trees') => binary search, dsu, trees
# ('math',) =>
# ('binary search', 'bitmasks', 'constructive algorithms', 'dfs and similar', 'graphs', 'trees') => binary search, bitmasks, constructive algorithms, dfs and similar, graphs, trees
# ('binary search', 'data structures') => binary search, data structures
# ('brute force', 'dfs and similar', 'math', 'number theory') => dp, greedy
# ('bitmasks', 'math', 'number theory') => brute force, math, number theory
# ('brute force', 'implementation') => brute force, implementation
# ('binary search', 'data structures') => binary search
# ('binary search', 'data structures') => binary search, data structures
# ('greedy',) => implementation, math
# ('greedy', 'implementation') => greedy, implementation
# ('binary search', 'dfs and similar', 'math', 'meet-in-the-middle', 'number theory', 'two pointers') => binary search, dfs and similar, math, meet-in-the-middle, number theory, two pointers
# ('constructive algorithms', 'dfs and similar', 'graphs', 'greedy', 'trees') => constructive algorithms, dfs and similar, graphs, greedy, trees
# ('implementation', 'math') => math
# ('implementation', 'math') => implementation, math
# ('data structures', 'dp', 'greedy', 'implementation') => data structures, dp, greedy, implementation
# ('brute force', 'implementation') => brute force, implementation
# ('implementation', 'sortings') => implementation
# ('brute force', 'hashing', 'implementation', 'math', 'strings') => brute force, hashing, implementation, math, strings
# ('data structures', 'dp', 'number theory') => data structures, dp, number theory
# ('brute force', 'combinatorics', 'math', 'number theory', 'probabilities') => combinatorics, math
# ('dfs and similar', 'dsu', 'graphs', 'trees') => dfs and similar, dsu, graphs, trees
# ('implementation', 'strings') => implementation, strings
# ('implementation',) => implementation
# ('binary search', 'greedy') => binary search, greedy
# ('fft', 'math', 'strings') => fft, math, strings
# ('dfs and similar', 'dp', 'dsu', 'graphs') => dfs and similar, dp, graphs
# ('data structures', 'geometry') => data structures, geometry
# ('data structures', 'implementation') => data structures, implementation
# ('data structures', 'number theory') => math
# ('implementation', 'strings') => implementation, strings
# ('implementation',) => implementation
# ('dfs and similar', 'dp', 'math', 'trees') => dfs and similar, math, trees
# ('implementation', 'math', 'number theory') => implementation, math, number theory
# ('data structures', 'dp', 'greedy', 'implementation') => data structures, dp, greedy, implementation
# ('dfs and similar', 'trees') => dfs and similar, trees
# ('implementation',) => implementation
# ('dfs and similar', 'dp', 'greedy') => dfs and similar, dp, greedy
# ('dp', 'strings', 'two pointers') => dp, strings, two pointers
# ('implementation', 'strings') => implementation, strings
# ('bitmasks', 'divide and conquer', 'dp') => bitmasks, divide and conquer, dp
# ('dp', 'greedy', 'math', 'number theory') => math
# ('geometry', 'math') => geometry, math
# ('constructive algorithms', 'geometry', 'greedy', 'math', 'number theory', 'sortings') => greedy, implementation, sortings
# ('dfs and similar', 'graphs', 'trees') => dfs and similar, graphs, trees
# ('bitmasks', 'dp') => bitmasks, dp
# ('greedy', 'math', 'number theory') => constructive algorithms, math
# ('implementation', 'sortings') => implementation, sortings
# ('implementation',) => implementation
# ('data structures',) => graphs, greedy
# ('brute force', 'dp', 'hashing', 'strings') => brute force, strings
# ('flows', 'graph matchings') => flows, graph matchings
# ('binary search', 'data structures', 'dp', 'dsu') => dp
# ('data structures', 'dsu', 'graphs') => data structures, dsu
# ('constructive algorithms', 'greedy', 'sortings') => constructive algorithms, greedy, sortings
# ('dfs and similar', 'graphs', 'shortest paths') => dfs and similar, graphs, shortest paths
# ('brute force', 'implementation') => brute force, implementation
# ('constructive algorithms', 'math') => constructive algorithms, math
# ('combinatorics', 'dp', 'matrices', 'strings') => combinatorics, dp, matrices, strings
# ('math',) => math
# ...
# ('binary search', 'bitmasks', 'greedy') => binary search, bitmasks, greedy
# ('data structures', 'dfs and similar', 'dp', 'graphs', 'trees') => data structures, dfs and similar, dp, graphs, trees
# ('combinatorics', 'greedy', 'implementation', 'math') => combinatorics, greedy, implementation, math
# ('constructive algorithms', 'greedy', 'implementation') => implementation, math
# ('bitmasks', 'combinatorics', 'dp') => bitmasks, combinatorics, dp
# ('math', 'number theory') => math, number theory
# ('constructive algorithms', 'math') => implementation, math
# ('brute force', 'implementation') => brute force, implementation
# ('combinatorics', 'dfs and similar', 'graphs', 'trees') => combinatorics, dfs and similar, graphs, trees
# ('brute force', 'dp', 'implementation', 'sortings') => brute force, dp, sortings
# ('implementation',) => implementation
# ('flows', 'graph matchings') =>
# ('geometry',) => geometry
# ('dfs and similar', 'graphs') => brute force
# ('bitmasks', 'dp', 'greedy') =>
# ('fft', 'math', 'number theory') => fft, math, number theory
# ('geometry',) => geometry
# ('dp', 'math') => dp, math
# ('bitmasks', 'dp') => bitmasks, dp
# ('bitmasks', 'brute force', 'combinatorics', 'dp', 'number theory') => bitmasks, brute force, combinatorics, dp, number theory
# ('brute force', 'greedy', 'implementation') => brute force, greedy, implementation
# ('binary search', 'geometry', 'hashing', 'sortings') =>
# ('data structures', 'greedy') => data structures, greedy
# ('dp', 'sortings') => dp, greedy, sortings
# ('implementation',) => implementation
# ('brute force', 'geometry') => brute force, geometry
# ('binary search', 'brute force', 'data structures', 'implementation') => binary search, brute force, data structures, implementation
# ('brute force', 'constructive algorithms', 'geometry', 'trees') => brute force, constructive algorithms, geometry, trees
# ('implementation',) => brute force, implementation
# ('greedy',) => sortings
# ('brute force', 'constructive algorithms') => brute force, constructive algorithms
# ('brute force', 'implementation') => brute force, greedy, implementation
# ('dp', 'math', 'number theory', 'probabilities') => dp, math, number theory, probabilities
# ('constructive algorithms', 'graphs', 'implementation') => constructive algorithms, graphs, implementation
# ('games',) => games
# ('dp', 'graph matchings', 'math', 'trees') => dp, trees
# ('brute force', 'implementation', 'strings') => strings
# ('math',) => math
# ('brute force',) => brute force
# ('binary search', 'data structures', 'probabilities', 'sortings') => binary search, data structures, probabilities, sortings
# ('brute force', 'geometry') => brute force, geometry
# ('dfs and similar', 'dp', 'graphs', 'trees') => dfs and similar, dp, graphs, trees
# ('binary search', 'brute force', 'dfs and similar', 'dp', 'sortings', 'trees') => dfs and similar
# ('constructive algorithms',) => constructive algorithms, math
# ('constructive algorithms', 'data structures') => data structures
# ('dp',) => dp
# ('brute force', 'dfs and similar', 'dsu', 'graphs') => brute force, dfs and similar, dsu, graphs
# ('greedy', 'math') => greedy, math
# ('data structures',) => data structures
# ('brute force', 'constructive algorithms', 'geometry') => brute force, constructive algorithms, geometry
# ('strings',) => strings
# ('brute force', 'dp', 'math', 'probabilities') => brute force, dp, math, probabilities
# ('dfs and similar', 'dp', 'two pointers') => dfs and similar, dp, two pointers
# ('data structures', 'dp', 'math', 'sortings') => data structures, dp, math, sortings
# ('implementation',) => implementation
# ('dp', 'fft') => dp, fft
# ('data structures', 'hashing', 'strings') => data structures, hashing, strings
# ('implementation', 'strings') => implementation, strings
# ('binary search', 'greedy') => binary search, greedy
# ('implementation', 'sortings', 'strings') => implementation, sortings, strings
# ('brute force', 'implementation', 'sortings') => brute force, implementation, sortings
# ('brute force', 'implementation', 'math') => implementation
# ('implementation',) => implementation
# ('geometry',) => geometry
# ('constructive algorithms', 'graphs', 'trees') => constructive algorithms, graphs, trees
# ('brute force', 'greedy', 'implementation') => brute force, greedy, implementation
# ('brute force', 'greedy') => brute force, greedy
# ('implementation',) => implementation
# ('bitmasks', 'combinatorics', 'dp', 'math', 'number theory') => bitmasks, combinatorics, dp, math, number theory
# ('dp', 'greedy') => dp, greedy
# ('data structures', 'dp', 'string suffix structures') => data structures, dp
# ('brute force', 'greedy') => implementation, math
# ('constructive algorithms', 'math') => constructive algorithms, math
# ('constructive algorithms', 'dfs and similar', 'graphs', 'greedy') => constructive algorithms, dfs and similar, graphs, greedy
# ('data structures', 'greedy') => data structures, greedy
# ('probabilities',) => math
# ('bitmasks', 'brute force', 'implementation') =>
# ('data structures', 'implementation') =>
# ('dfs and similar', 'greedy') => graphs, greedy
# ('constructive algorithms',) => constructive algorithms
# ('implementation',) => implementation
# ('binary search', 'geometry', 'sortings') => binary search, geometry, sortings
# ('implementation', 'math') => implementation
# ('dp', 'expression parsing') => dp, expression parsing
# ('implementation', 'strings') => implementation, strings
# ('constructive algorithms',) => implementation
# ('dp', 'greedy', 'implementation') => greedy, implementation, sortings
# ('brute force', 'math') => brute force, math
# ('constructive algorithms', 'greedy', 'math') => dfs and similar, implementation
# ('implementation',) => implementation
# ('dfs and similar', 'dp', 'graphs', 'trees') => dfs and similar, dp, graphs, trees
# ('implementation',) => implementation
# ('constructive algorithms', 'greedy') => constructive algorithms, greedy
# ('brute force', 'geometry') => implementation, math
# ('geometry', 'probabilities') => geometry, probabilities
# ('math',) => implementation
# ('brute force', 'dp') => brute force, dp
# ('data structures', 'implementation', 'math', 'two pointers') => data structures, implementation, math, two pointers
# ('bitmasks', 'combinatorics', 'number theory') => combinatorics
# ('implementation',) => implementation
# ('bitmasks', 'brute force', 'dp') => bitmasks, brute force, dp
# ('data structures', 'dp') => data structures, dp
# ('greedy',) => greedy
# ('dp', 'string suffix structures', 'trees') => dp, string suffix structures, trees
# ('brute force', 'dp', 'implementation') => brute force, dp, implementation
# ('brute force', 'constructive algorithms', 'geometry') => brute force, constructive algorithms, geometry
# ('dp', 'probabilities', 'sortings') => dp, probabilities, sortings
# ('implementation',) => implementation
# ('math', 'probabilities') => math, probabilities
# ('*special', 'dfs and similar', 'dp', 'graphs', 'trees') => *special, dfs and similar, dp, graphs, trees
# ('implementation', 'strings') => greedy
# ('implementation',) => implementation
# ('combinatorics', 'math', 'number theory') => binary search, math
# ('binary search', 'implementation', 'math', 'number theory') => binary search, implementation, math, number theory
# ('brute force',) => brute force
# ('greedy', 'math') => implementation
# ('dfs and similar', 'graphs') => dfs and similar, graphs
# ('*special', 'implementation') => *special, implementation
# ('greedy',) => implementation
# ('combinatorics', 'dp', 'graphs', 'shortest paths') => combinatorics, dp, graphs, shortest paths
# ('dp', 'math', 'probabilities') => dp, math, probabilities
# ('implementation', 'math', 'number theory') => implementation
# ('constructive algorithms', 'geometry') => constructive algorithms, geometry
# ('binary search', 'implementation', 'two pointers') => binary search, implementation, two pointers
# ('greedy', 'math') => greedy, math
# ('constructive algorithms', 'games') => constructive algorithms, games
# ('math',) => implementation, math
# ('implementation',) => implementation
# ('implementation',) => implementation
# ('brute force', 'constructive algorithms') => brute force, constructive algorithms
# ('constructive algorithms', 'sortings') => sortings
# ('implementation', 'math') => implementation
# ('binary search', 'brute force', 'data structures', 'implementation') => binary search, brute force, data structures, implementation
# ('implementation', 'math') => implementation, math
# ('graphs', 'shortest paths') => graphs, shortest paths
# ('dp', 'math', 'probabilities') => dp, math, probabilities
# ('greedy',) => data structures, greedy
# ('constructive algorithms', 'dfs and similar', 'trees') => constructive algorithms, dfs and similar, trees
# ('binary search', 'brute force', 'implementation') => binary search, brute force, implementation
# ('dfs and similar', 'dp', 'dsu', 'graphs', 'implementation', 'trees') => dfs and similar, dp, dsu, graphs, implementation, trees
# ('binary search', 'dp', 'graphs') => binary search, dp, graphs
# ('data structures', 'dp', 'trees') => data structures, trees
# ('combinatorics', 'dp', 'probabilities') => combinatorics, dp, probabilities
# ('binary search', 'brute force', 'implementation') => binary search, brute force, implementation
# ('greedy', 'implementation') => greedy, implementation
# ('binary search', 'dfs and similar', 'math', 'meet-in-the-middle', 'number theory', 'two pointers') => binary search, dfs and similar, math, meet-in-the-middle, number theory, two pointers
# ('greedy', 'implementation') => greedy, implementation
# ('constructive algorithms', 'math') => math
# ('geometry',) => geometry
# ('data structures', 'probabilities') => math, probabilities
# ('dfs and similar', 'divide and conquer', 'dp', 'graphs', 'sortings', 'trees') => dfs and similar, divide and conquer, dp, graphs, sortings, trees
# ('binary search', 'data structures', 'greedy', 'sortings') => data structures, greedy, sortings
# ('combinatorics', 'dp', 'math', 'number theory') => combinatorics, dp, math
# ('brute force', 'constructive algorithms') => brute force, constructive algorithms
# ('greedy',) => greedy
# ('implementation', 'sortings') => implementation, sortings
# ('binary search', 'dp', 'probabilities') => binary search, dp, probabilities
# ('implementation',) => implementation
# ('binary search', 'data structures', 'implementation') => binary search, data structures, implementation
# ('data structures', 'hashing', 'sortings', 'strings') => data structures, hashing, sortings, strings
# ('brute force', 'implementation', 'sortings') => brute force, greedy, implementation, sortings
# ('brute force', 'dfs and similar', 'dp', 'strings') => brute force, dfs and similar, dp, strings
# ('implementation', 'sortings') => implementation
# ('dfs and similar', 'greedy', 'shortest paths') => greedy, shortest paths
# ('dp', 'strings') => dp, strings
# ('geometry', 'math') => geometry, math
# ('dfs and similar', 'graphs', 'greedy') =>
# ('constructive algorithms', 'data structures', 'greedy', 'math') => constructive algorithms, math
# ('implementation', 'sortings') => implementation, sortings
# ('geometry',) => geometry
# ('data structures', 'dp', 'trees') => data structures, dp, trees
# ('implementation', 'sortings') => implementation, sortings
# ('implementation', 'math') => implementation, math
# ('greedy',) => sortings
# ('data structures', 'dp') => data structures, dp
# ('data structures', 'dfs and similar', 'dp', 'trees') => data structures, dfs and similar, dp, trees
# ('dfs and similar', 'graphs', 'implementation', 'shortest paths') => dfs and similar, graphs, implementation, shortest paths
# ('data structures',) => data structures
# ('graph matchings', 'strings') => graph matchings, strings
# ('dfs and similar', 'graphs', 'sortings') => graphs, math
# ('constructive algorithms', 'math') => constructive algorithms, math
# ('binary search', 'two pointers') => implementation
# ('binary search', 'sortings', 'ternary search') => data structures, greedy, sortings
# ('constructive algorithms', 'sortings') => constructive algorithms, sortings
# ('brute force', 'greedy') => brute force, greedy
# ('implementation',) => implementation
# ('implementation',) => implementation
# ('greedy', 'implementation', 'math') => implementation
# ('data structures', 'geometry', 'two pointers') => data structures, geometry, two pointers
# ('dp', 'greedy') => dp, greedy
# ('dp', 'graphs') => combinatorics, dp
# ('math', 'strings') => math, strings
# ('implementation',) => implementation
# ('dp', 'matrices') => dp, matrices
# ('binary search', 'data structures', 'dp', 'greedy', 'two pointers') => binary search, data structures, sortings
# ('constructive algorithms', 'implementation') => constructive algorithms, implementation
# ('dfs and similar', 'graphs', 'implementation') => dfs and similar, graphs, implementation
# ('combinatorics', 'dp', 'graphs', 'shortest paths') => combinatorics, dp, graphs, shortest paths
# ('implementation',) => greedy, implementation
# ('combinatorics', 'dp', 'probabilities') => combinatorics, dp, probabilities
# ('greedy', 'implementation') => implementation, math
# ('brute force', 'combinatorics', 'constructive algorithms', 'math') => combinatorics, constructive algorithms, math
# ('data structures',) => data structures
# ('brute force', 'greedy', 'implementation') => brute force, greedy, implementation
# ('data structures', 'dsu', 'string suffix structures', 'strings') => data structures, dsu, string suffix structures, strings
# ('implementation',) => implementation
# ('data structures', 'dsu', 'trees') => data structures, graphs, trees
# ('data structures', 'dfs and similar', 'trees') => data structures, dfs and similar, trees
# ('implementation',) => implementation
# ('dp', 'implementation') => dp, implementation
# ('dp',) => dp
# ('implementation',) => implementation
# ('constructive algorithms', 'geometry') => constructive algorithms, geometry
# ('constructive algorithms', 'greedy') => constructive algorithms, greedy
# ('math',) => math
# ('combinatorics', 'number theory') => combinatorics, number theory
# ('brute force', 'greedy') => brute force, greedy
# ('implementation', 'math') => math
# ('implementation',) => greedy, implementation
# ('data structures', 'strings') => data structures, strings
# ('data structures', 'dp', 'trees') => data structures, dp, trees
# ('brute force',) => brute force
# ('brute force', 'math') => brute force, math
# ('binary search', 'data structures', 'implementation', 'sortings') => binary search, data structures, implementation, sortings
# ('implementation', 'sortings') => implementation
# ('data structures',) => data structures
# ('geometry',) => geometry
# ('data structures', 'divide and conquer', 'trees') => data structures, divide and conquer, trees
# ('data structures', 'divide and conquer') => data structures, divide and conquer
# ('binary search', 'brute force', 'dp', 'two pointers') => binary search, brute force, dp, two pointers
# ('combinatorics', 'math', 'number theory') => combinatorics, math, number theory
# ('data structures', 'implementation') => data structures, implementation
# ('implementation', 'sortings', 'strings') => implementation, sortings, strings
# ('constructive algorithms', 'math') => constructive algorithms, greedy
# ('games',) => games
# ('implementation',) => implementation
# ('dp',) => dp
# ('binary search', 'bitmasks', 'brute force') => binary search, bitmasks, brute force
# ('strings',) =>
# ('constructive algorithms', 'implementation') => geometry, implementation
# ('implementation',) => greedy, implementation, math
# ('constructive algorithms', 'implementation', 'sortings') => implementation
# ('implementation',) => implementation
# ('dfs and similar', 'graphs') => dfs and similar, graphs
# ('brute force', 'probabilities') => brute force
# ('math',) => implementation, math
# ('dfs and similar', 'graphs') => dfs and similar, graphs
# ('greedy', 'implementation', 'sortings') => greedy, implementation, sortings
# ('constructive algorithms', 'data structures', 'implementation') => constructive algorithms, data structures, implementation
# ('combinatorics', 'dp') =>
# ('brute force', 'dp') => brute force, dp
# ('brute force', 'dfs and similar', 'dsu') => brute force, dfs and similar, dsu
# ('brute force', 'dp') => brute force, dp
# ('implementation', 'math') => greedy, math
